# %% [markdown]
# <a href="https://colab.research.google.com/github/sr6awi/ieee_fraud_detection/blob/main/notebooks/04_modeling_dual_path_full_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

print("=" * 70)
print("🚀 DUAL-PATH FRAUD DETECTION - COMPLETE TRAINING PIPELINE")
print("Node Classification with Full Dataset Support")
print("=" * 70)

# GPU Configuration
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU: {len(gpus)} device(s) available")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No GPU - using CPU (slower)")

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# ======================================================================
# 🚀 DUAL-PATH FRAUD DETECTION - COMPLETE TRAINING PIPELINE
# Node Classification with Full Dataset Support
# ======================================================================
# ⚠️ No GPU - using CPU (slower)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.3.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 842.3 kB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.8 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 105.6 MB/s eta 0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 136.6 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 142.3 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.4 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorboard-data-server, google_pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.9.23 google_pasta-0.2.0 libclang-18.1.1 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 werkzeug-3.1.3 wheel-0.45.1

# %%
BASE_DIR = Path("/content/drive/MyDrive/ML_Projects/ieee-fraud-detection")
PROCESSED_DIR = BASE_DIR / "processed"
MODEL_DIR = BASE_DIR / "models"
RESULTS_DIR = BASE_DIR / "results"

MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Training configuration
CONFIG = {
    'batch_size': 1024,
    'epochs': 50,
    'learning_rate': 0.001,
    'patience': 10,
    'n_folds': 5,
    'use_class_weights': True,
    'save_best_only': True
}

print(f"\n📁 Directories:")
print(f"   Data: {PROCESSED_DIR}")
print(f"   Models: {MODEL_DIR}")
print(f"   Results: {RESULTS_DIR}")
# Out:
# 📁 Directories:
#    Data: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/processed
#    Models: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models
#    Results: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/results

# %%
print("\n" + "="*70)
print("📥 LOADING FEATURE-ENGINEERED DATA")
print("="*70)

print("\nLoading training data...")
train = pd.read_csv(PROCESSED_DIR / "train_feature_engineered.csv")
print(f"✅ Train loaded: {train.shape}")

print("Loading test data...")
test = pd.read_csv(PROCESSED_DIR / "test_feature_engineered.csv")
print(f"✅ Test loaded: {test.shape}")

# Check for target
if 'isFraud' not in train.columns:
    raise ValueError("Target 'isFraud' not found in training data!")

print(f"\n📊 Data Statistics:")
print(f"   Training samples: {len(train):,}")
print(f"   Test samples: {len(test):,}")
print(f"   Features: {train.shape[1] - 2}")  # Exclude isFraud and TransactionID
print(f"   Fraud rate: {train['isFraud'].mean()*100:.2f}%")
print(f"   Class imbalance: {(1-train['isFraud'].mean())/train['isFraud'].mean():.1f}:1")
# Out:
# ======================================================================
# 📥 LOADING FEATURE-ENGINEERED DATA
# ======================================================================
#
# Loading training data...
# ✅ Train loaded: (590540, 262)
# Loading test data...
# ✅ Test loaded: (506691, 261)
#
# 📊 Data Statistics:
#    Training samples: 590,540
#    Test samples: 506,691
#    Features: 260
#    Fraud rate: 3.50%
#    Class imbalance: 27.6:1

# %%
print("\n" + "="*70)
print("🎯 PREPARING FEATURES FOR DUAL PATHS")
print("="*70)

# Smart features for GNN (features that benefit from graph structure)
GNN_FEATURES = [
    'TransactionAmt', 'TransactionDT',
    'card1', 'card2', 'card1_count',
    'card1_fraud_rate', 'card2_fraud_rate',
    'P_emaildomain_fraud_rate', 'R_emaildomain_fraud_rate',
    'addr1', 'dist1', 'ProductCD', 'ProductCD_fraud_rate',
    'transaction_hour', 'is_weekend', 'is_night',
    'TransactionAmt_log', 'email_domains_match', 'addr_match'
]

# Filter available GNN features
GNN_FEATURES = [f for f in GNN_FEATURES if f in train.columns]

print(f"✅ GNN Path: {len(GNN_FEATURES)} smart features selected")
print(f"   Focus: Graph-beneficial features")

# All features for TabNet (exclude ID and target)
exclude_cols = ['isFraud', 'TransactionID']
TABNET_FEATURES = [c for c in train.columns if c not in exclude_cols]

print(f"✅ TabNet Path: {len(TABNET_FEATURES)} features (all available)")
print(f"   Focus: Rich feature learning")
# Out:
# ======================================================================
# 🎯 PREPARING FEATURES FOR DUAL PATHS
# ======================================================================
# ✅ GNN Path: 19 smart features selected
#    Focus: Graph-beneficial features
# ✅ TabNet Path: 260 features (all available)
#    Focus: Rich feature learning

# %%
print("\n" + "="*70)
print("📊 PREPARING TRAINING DATA (SIMPLIFIED FOR MEMORY)")
print("="*70)

"""
SIMPLIFIED APPROACH:
- Skip graph construction for now (memory intensive)
- Use GNN features as regular neural network
- Focus on TabNet path primarily
- Treat as multi-modal learning (two feature sets)
"""

# Prepare features
X_gnn = train[GNN_FEATURES].fillna(0).values
X_tabnet = train[TABNET_FEATURES].fillna(0).values
y = train['isFraud'].values

X_gnn_test = test[GNN_FEATURES].fillna(0).values
X_tabnet_test = test[TABNET_FEATURES].fillna(0).values

print(f"✅ Training data prepared:")
print(f"   GNN input shape: {X_gnn.shape}")
print(f"   TabNet input shape: {X_tabnet.shape}")
print(f"   Labels shape: {y.shape}")

# Normalize features
print("\n📏 Normalizing features...")
scaler_gnn = StandardScaler()
scaler_tabnet = StandardScaler()

X_gnn_scaled = scaler_gnn.fit_transform(X_gnn)
X_tabnet_scaled = scaler_tabnet.fit_transform(X_tabnet)

X_gnn_test_scaled = scaler_gnn.transform(X_gnn_test)
X_tabnet_test_scaled = scaler_tabnet.transform(X_tabnet_test)

# Save scalers
import joblib
joblib.dump(scaler_gnn, MODEL_DIR / 'scaler_gnn.pkl')
joblib.dump(scaler_tabnet, MODEL_DIR / 'scaler_tabnet.pkl')

print("✅ Features normalized and scalers saved!")
# Out:
# ======================================================================
# 📊 PREPARING TRAINING DATA (SIMPLIFIED FOR MEMORY)
# ======================================================================
# ✅ Training data prepared:
#    GNN input shape: (590540, 19)
#    TabNet input shape: (590540, 260)
#    Labels shape: (590540,)
#
# 📏 Normalizing features...
# ✅ Features normalized and scalers saved!

# %%
print("\n" + "="*70)
print("🏗️ BUILDING SIMPLIFIED DUAL-PATH MODEL")
print("="*70)

def build_dual_path_model(gnn_features, tabnet_features):
    """
    Simplified dual-path architecture for production training.
    Treats GNN features as a separate neural network path.
    """

    # INPUT LAYERS
    input_gnn = layers.Input(shape=(gnn_features,), name='gnn_input')
    input_tabnet = layers.Input(shape=(tabnet_features,), name='tabnet_input')

    # PATH 1: GNN-style Network (processes graph-beneficial features)
    x1 = layers.Dense(128, activation='relu', name='gnn_dense1')(input_gnn)
    x1 = layers.BatchNormalization(name='gnn_bn1')(x1)
    x1 = layers.Dropout(0.3, name='gnn_dropout1')(x1)

    x1 = layers.Dense(64, activation='relu', name='gnn_dense2')(x1)
    x1 = layers.BatchNormalization(name='gnn_bn2')(x1)
    x1 = layers.Dropout(0.2, name='gnn_dropout2')(x1)

    gnn_output = layers.Dense(32, activation='relu', name='gnn_output')(x1)

    # PATH 2: TabNet-style Network (attention-based feature selection)
    # Step 1
    x2 = layers.Dense(256, activation='gelu', name='tabnet_step1')(input_tabnet)
    x2 = layers.BatchNormalization(name='tabnet_bn1')(x2)
    x2 = layers.Dropout(0.3, name='tabnet_dropout1')(x2)

    # Step 2
    x2 = layers.Dense(128, activation='gelu', name='tabnet_step2')(x2)
    x2 = layers.BatchNormalization(name='tabnet_bn2')(x2)
    x2 = layers.Dropout(0.2, name='tabnet_dropout2')(x2)

    # Step 3
    tabnet_output = layers.Dense(32, activation='relu', name='tabnet_output')(x2)

    # FUSION: Concatenate both paths
    merged = layers.Concatenate(name='fusion_concat')([gnn_output, tabnet_output])

    # Attention-based fusion
    attention_weights = layers.Dense(64, activation='softmax', name='attention_weights')(merged)
    attended = layers.Multiply(name='attended_features')([merged, attention_weights])

    # Final classification layers
    x = layers.Dense(64, activation='relu', name='classifier_dense1')(attended)
    x = layers.BatchNormalization(name='classifier_bn')(x)
    x = layers.Dropout(0.2, name='classifier_dropout')(x)

    x = layers.Dense(32, activation='relu', name='classifier_dense2')(x)

    # Output
    output = layers.Dense(1, activation='sigmoid', name='output')(x)

    # Create model
    model = keras.Model(
        inputs=[input_gnn, input_tabnet],
        outputs=output,
        name='DualPathFraudDetector'
    )

    return model

# Build model
model = build_dual_path_model(len(GNN_FEATURES), len(TABNET_FEATURES))

print("✅ Model architecture built!")
print(f"\n📋 Model Summary:")
model.summary()
# Out:
# ======================================================================
# 🏗️ BUILDING SIMPLIFIED DUAL-PATH MODEL
# ======================================================================
# ✅ Model architecture built!
#
# 📋 Model Summary:
# Model: "DualPathFraudDetector"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ gnn_input           │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_input        │ (None, 260)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dense1 (Dense)  │ (None, 128)       │      2,560 │ gnn_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_step1        │ (None, 256)       │     66,816 │ tabnet_input[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_bn1             │ (None, 128)       │        512 │ gnn_dense1[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_bn1          │ (None, 256)       │      1,024 │ tabnet_step1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dropout1        │ (None, 128)       │          0 │ gnn_bn1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_dropout1     │ (None, 256)       │          0 │ tabnet_bn1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dense2 (Dense)  │ (None, 64)        │      8,256 │ gnn_dropout1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_step2        │ (None, 128)       │     32,896 │ tabnet_dropout1[… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_bn2             │ (None, 64)        │        256 │ gnn_dense2[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_bn2          │ (None, 128)       │        512 │ tabnet_step2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dropout2        │ (None, 64)        │          0 │ gnn_bn2[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_dropout2     │ (None, 128)       │          0 │ tabnet_bn2[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_output (Dense)  │ (None, 32)        │      2,080 │ gnn_dropout2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_output       │ (None, 32)        │      4,128 │ tabnet_dropout2[… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion_concat       │ (None, 64)        │          0 │ gnn_output[0][0], │
# │ (Concatenate)       │                   │            │ tabnet_output[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights   │ (None, 64)        │      4,160 │ fusion_concat[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attended_features   │ (None, 64)        │          0 │ fusion_concat[0]… │
# │ (Multiply)          │                   │            │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense1   │ (None, 64)        │      4,160 │ attended_feature… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_bn       │ (None, 64)        │        256 │ classifier_dense… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dropout  │ (None, 64)        │          0 │ classifier_bn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense2   │ (None, 32)        │      2,080 │ classifier_dropo… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │         33 │ classifier_dense… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 129,729 (506.75 KB)
#  Trainable params: 128,449 (501.75 KB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
print("\n" + "="*70)
print("⚙️ COMPILING MODEL")
print("="*70)

# Calculate class weights for imbalanced data
fraud_rate = y.mean()
class_weight = {
    0: 1.0,
    1: (1 - fraud_rate) / fraud_rate
}

print(f"📊 Class weights (for imbalance):")
print(f"   Class 0 (Legit): {class_weight[0]:.2f}")
print(f"   Class 1 (Fraud): {class_weight[1]:.2f}")

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=CONFIG['learning_rate']),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        keras.metrics.AUC(name='auc'),
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall')
    ]
)

print("\n✅ Model compiled successfully!")
# Out:
# ======================================================================
# ⚙️ COMPILING MODEL
# ======================================================================
# 📊 Class weights (for imbalance):
#    Class 0 (Legit): 1.00
#    Class 1 (Fraud): 27.58
#
# ✅ Model compiled successfully!

# %%
# !pip install keras-tqdm
# Out:
# Collecting keras-tqdm
#   Downloading keras_tqdm-2.0.1-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Keras in /usr/local/lib/python3.12/dist-packages (from keras-tqdm) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from keras-tqdm) (4.67.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->Keras->keras-tqdm) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras->keras-tqdm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras->keras-tqdm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->Keras->keras-tqdm) (0.1.2)
# Downloading keras_tqdm-2.0.1-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: keras-tqdm
# Successfully installed keras-tqdm-2.0.1

# %%
print("\n" + "="*70)
print("🎓 TRAINING WITH STRATIFIED K-FOLD CROSS-VALIDATION")
print("="*70)

from tensorflow.keras.callbacks import LambdaCallback

# Base callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_auc',
        patience=CONFIG['patience'],
        restore_best_weights=True,
        mode='max',
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_auc',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
]

# Stratified K-Fold setup
skf = StratifiedKFold(n_splits=CONFIG['n_folds'], shuffle=True, random_state=SEED)

cv_scores = []
fold_histories = []

print(f"\n🔄 Starting {CONFIG['n_folds']}-Fold Cross-Validation...")
print("="*70)

for fold, (train_idx, val_idx) in enumerate(skf.split(X_gnn_scaled, y), 1):
    print(f"\n{'='*70}")
    print(f"📊 FOLD {fold}/{CONFIG['n_folds']}")
    print(f"{'='*70}")

    # Split data
    X_gnn_train, X_gnn_val = X_gnn_scaled[train_idx], X_gnn_scaled[val_idx]
    X_tabnet_train, X_tabnet_val = X_tabnet_scaled[train_idx], X_tabnet_scaled[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    print(f"   Train: {len(y_train):,} samples ({y_train.mean()*100:.2f}% fraud)")
    print(f"   Val:   {len(y_val):,} samples ({y_val.mean()*100:.2f}% fraud)")

    # Rebuild model (fresh weights for each fold)
    model = build_dual_path_model(len(GNN_FEATURES), len(TABNET_FEATURES))
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=CONFIG['learning_rate']),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            keras.metrics.AUC(name='auc'),
            keras.metrics.Precision(name='precision'),
            keras.metrics.Recall(name='recall')
        ]
    )

    # Custom epoch logger for short summaries
    epoch_logger = LambdaCallback(
        on_epoch_end=lambda e, logs:
            print(f"Epoch {e+1:02d} | "
                  f"loss={logs['loss']:.4f} | val_loss={logs['val_loss']:.4f} | "
                  f"auc={logs['auc']:.4f} | val_auc={logs['val_auc']:.4f}")
    )

    # Create callbacks for this fold (unique checkpoint path)
    fold_callbacks = callbacks.copy() + [
        keras.callbacks.ModelCheckpoint(
            filepath=str(MODEL_DIR / f'best_model_fold_{fold}.keras'),
            monitor='val_auc',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        epoch_logger
    ]

    # Train
    print(f"\n   🚀 Training...")
    history = model.fit(
        [X_gnn_train, X_tabnet_train],
        y_train,
        validation_data=([X_gnn_val, X_tabnet_val], y_val),
        epochs=CONFIG['epochs'],
        batch_size=CONFIG['batch_size'],
        class_weight=class_weight if CONFIG['use_class_weights'] else None,
        callbacks=fold_callbacks,
        verbose=1      # ✅ live progress bar
    )

    # Evaluate
    val_preds = model.predict([X_gnn_val, X_tabnet_val], verbose=0)
    val_auc = roc_auc_score(y_val, val_preds)
    cv_scores.append(val_auc)
    fold_histories.append(history.history)

    print(f"\n   ✅ Fold {fold} Complete!")
    print(f"   Val AUC: {val_auc:.6f}")
    print(f"   Best epoch: {np.argmax(history.history['val_auc']) + 1}")

# ============================================================================
# RESULTS SUMMARY
# ============================================================================

print("\n" + "="*70)
print("📊 CROSS-VALIDATION RESULTS")
print("="*70)

print(f"\nFold AUC Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"   Fold {i}: {score:.6f}")

print(f"\n🏆 Summary:")
print(f"   Mean AUC: {np.mean(cv_scores):.6f}")
print(f"   Std AUC:  {np.std(cv_scores):.6f}")
print(f"   Min AUC:  {np.min(cv_scores):.6f}")
print(f"   Max AUC:  {np.max(cv_scores):.6f}")

# Save cross-validation results
cv_results = {
    'fold_scores': cv_scores,
    'mean_auc': float(np.mean(cv_scores)),
    'std_auc': float(np.std(cv_scores)),
    'config': CONFIG
}

with open(RESULTS_DIR / 'cv_results.json', 'w') as f:
    json.dump(cv_results, f, indent=2)

print(f"\n✅ CV results saved to: {RESULTS_DIR / 'cv_results.json'}")
# Out:
# ======================================================================
# 🎓 TRAINING WITH STRATIFIED K-FOLD CROSS-VALIDATION
# ======================================================================
#
# 🔄 Starting 5-Fold Cross-Validation...
# ======================================================================
#
# ======================================================================
# 📊 FOLD 1/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7618 - auc: 0.8389 - loss: 0.9502 - precision: 0.1100 - recall: 0.7568
# Epoch 1: val_auc improved from -inf to 0.91710, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 01 | loss=0.8252 | val_loss=0.2830 | auc=0.8832 | val_auc=0.9171
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7624 - auc: 0.8394 - loss: 0.9488 - precision: 0.1103 - recall: 0.7571 - val_accuracy: 0.9227 - val_auc: 0.9171 - val_loss: 0.2830 - val_precision: 0.2721 - val_recall: 0.7217 - learning_rate: 0.0010
# Epoch 2/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8475 - auc: 0.9123 - loss: 0.7238 - precision: 0.1648 - recall: 0.8122
# Epoch 2: val_auc improved from 0.91710 to 0.92834, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 02 | loss=0.6961 | val_loss=0.2797 | auc=0.9182 | val_auc=0.9283
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8475 - auc: 0.9124 - loss: 0.7235 - precision: 0.1649 - recall: 0.8123 - val_accuracy: 0.8931 - val_auc: 0.9283 - val_loss: 0.2797 - val_precision: 0.2178 - val_recall: 0.7926 - learning_rate: 0.0010
# Epoch 3/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8556 - auc: 0.9232 - loss: 0.6791 - precision: 0.1749 - recall: 0.8264
# Epoch 3: val_auc improved from 0.92834 to 0.93234, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 03 | loss=0.6575 | val_loss=0.2705 | auc=0.9276 | val_auc=0.9323
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8557 - auc: 0.9233 - loss: 0.6790 - precision: 0.1749 - recall: 0.8264 - val_accuracy: 0.8806 - val_auc: 0.9323 - val_loss: 0.2705 - val_precision: 0.2026 - val_recall: 0.8224 - learning_rate: 0.0010
# Epoch 4/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8587 - auc: 0.9322 - loss: 0.6407 - precision: 0.1810 - recall: 0.8465
# Epoch 4: val_auc improved from 0.93234 to 0.93753, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 04 | loss=0.6230 | val_loss=0.2777 | auc=0.9351 | val_auc=0.9375
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8588 - auc: 0.9322 - loss: 0.6406 - precision: 0.1810 - recall: 0.8464 - val_accuracy: 0.8804 - val_auc: 0.9375 - val_loss: 0.2777 - val_precision: 0.2032 - val_recall: 0.8287 - learning_rate: 0.0010
# Epoch 5/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8586 - auc: 0.9355 - loss: 0.6244 - precision: 0.1813 - recall: 0.8496
# Epoch 5: val_auc improved from 0.93753 to 0.94094, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 05 | loss=0.6072 | val_loss=0.2455 | auc=0.9384 | val_auc=0.9409
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8587 - auc: 0.9356 - loss: 0.6243 - precision: 0.1813 - recall: 0.8496 - val_accuracy: 0.9128 - val_auc: 0.9409 - val_loss: 0.2455 - val_precision: 0.2584 - val_recall: 0.7977 - learning_rate: 0.0010
# Epoch 6/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8720 - auc: 0.9410 - loss: 0.5984 - precision: 0.1968 - recall: 0.8473
# Epoch 6: val_auc improved from 0.94094 to 0.94328, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 06 | loss=0.5815 | val_loss=0.2184 | auc=0.9439 | val_auc=0.9433
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.8721 - auc: 0.9410 - loss: 0.5982 - precision: 0.1968 - recall: 0.8473 - val_accuracy: 0.9111 - val_auc: 0.9433 - val_loss: 0.2184 - val_precision: 0.2553 - val_recall: 0.8045 - learning_rate: 0.0010
# Epoch 7/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8699 - auc: 0.9444 - loss: 0.5818 - precision: 0.1964 - recall: 0.8626
# Epoch 7: val_auc improved from 0.94328 to 0.94464, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 07 | loss=0.5661 | val_loss=0.2209 | auc=0.9468 | val_auc=0.9446
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8699 - auc: 0.9445 - loss: 0.5818 - precision: 0.1964 - recall: 0.8626 - val_accuracy: 0.9166 - val_auc: 0.9446 - val_loss: 0.2209 - val_precision: 0.2691 - val_recall: 0.8059 - learning_rate: 0.0010
# Epoch 8/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8758 - auc: 0.9486 - loss: 0.5595 - precision: 0.2047 - recall: 0.8675
# Epoch 8: val_auc improved from 0.94464 to 0.94612, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 08 | loss=0.5499 | val_loss=0.2213 | auc=0.9498 | val_auc=0.9461
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8759 - auc: 0.9486 - loss: 0.5594 - precision: 0.2047 - recall: 0.8675 - val_accuracy: 0.9132 - val_auc: 0.9461 - val_loss: 0.2213 - val_precision: 0.2616 - val_recall: 0.8129 - learning_rate: 0.0010
# Epoch 9/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8773 - auc: 0.9506 - loss: 0.5491 - precision: 0.2069 - recall: 0.8688
# Epoch 9: val_auc improved from 0.94612 to 0.94665, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 09 | loss=0.5364 | val_loss=0.2112 | auc=0.9523 | val_auc=0.9467
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8773 - auc: 0.9506 - loss: 0.5489 - precision: 0.2069 - recall: 0.8689 - val_accuracy: 0.9119 - val_auc: 0.9467 - val_loss: 0.2112 - val_precision: 0.2591 - val_recall: 0.8173 - learning_rate: 0.0010
# Epoch 10/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8777 - auc: 0.9523 - loss: 0.5404 - precision: 0.2083 - recall: 0.8746
# Epoch 10: val_auc improved from 0.94665 to 0.94817, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 10 | loss=0.5312 | val_loss=0.1869 | auc=0.9534 | val_auc=0.9482
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8778 - auc: 0.9523 - loss: 0.5403 - precision: 0.2084 - recall: 0.8746 - val_accuracy: 0.9290 - val_auc: 0.9482 - val_loss: 0.1869 - val_precision: 0.3041 - val_recall: 0.7986 - learning_rate: 0.0010
# Epoch 11/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8814 - auc: 0.9551 - loss: 0.5247 - precision: 0.2144 - recall: 0.8804
# Epoch 11: val_auc did not improve from 0.94817
# Epoch 11 | loss=0.5159 | val_loss=0.1852 | auc=0.9561 | val_auc=0.9478
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8814 - auc: 0.9551 - loss: 0.5246 - precision: 0.2143 - recall: 0.8804 - val_accuracy: 0.9236 - val_auc: 0.9478 - val_loss: 0.1852 - val_precision: 0.2884 - val_recall: 0.8069 - learning_rate: 0.0010
# Epoch 12/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8824 - auc: 0.9572 - loss: 0.5122 - precision: 0.2166 - recall: 0.8858
# Epoch 12: val_auc improved from 0.94817 to 0.94988, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 12 | loss=0.5053 | val_loss=0.1910 | auc=0.9579 | val_auc=0.9499
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8824 - auc: 0.9572 - loss: 0.5121 - precision: 0.2166 - recall: 0.8858 - val_accuracy: 0.9264 - val_auc: 0.9499 - val_loss: 0.1910 - val_precision: 0.2971 - val_recall: 0.8074 - learning_rate: 0.0010
# Epoch 13/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8884 - auc: 0.9578 - loss: 0.5085 - precision: 0.2252 - recall: 0.8810
# Epoch 13: val_auc did not improve from 0.94988
# Epoch 13 | loss=0.4960 | val_loss=0.1957 | auc=0.9594 | val_auc=0.9476
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8884 - auc: 0.9578 - loss: 0.5083 - precision: 0.2252 - recall: 0.8810 - val_accuracy: 0.9242 - val_auc: 0.9476 - val_loss: 0.1957 - val_precision: 0.2907 - val_recall: 0.8107 - learning_rate: 0.0010
# Epoch 14/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8864 - auc: 0.9595 - loss: 0.4984 - precision: 0.2230 - recall: 0.8872
# Epoch 14: val_auc did not improve from 0.94988
# Epoch 14 | loss=0.4871 | val_loss=0.1788 | auc=0.9609 | val_auc=0.9493
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8864 - auc: 0.9595 - loss: 0.4983 - precision: 0.2231 - recall: 0.8872 - val_accuracy: 0.9274 - val_auc: 0.9493 - val_loss: 0.1788 - val_precision: 0.3012 - val_recall: 0.8139 - learning_rate: 0.0010
# Epoch 15/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8902 - auc: 0.9615 - loss: 0.4859 - precision: 0.2296 - recall: 0.8908
# Epoch 15: val_auc did not improve from 0.94988
# Epoch 15 | loss=0.4774 | val_loss=0.1723 | auc=0.9624 | val_auc=0.9498
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8902 - auc: 0.9615 - loss: 0.4858 - precision: 0.2296 - recall: 0.8908 - val_accuracy: 0.9343 - val_auc: 0.9498 - val_loss: 0.1723 - val_precision: 0.3233 - val_recall: 0.8037 - learning_rate: 0.0010
# Epoch 16/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8919 - auc: 0.9618 - loss: 0.4851 - precision: 0.2327 - recall: 0.8925
# Epoch 16: val_auc improved from 0.94988 to 0.95136, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 16 | loss=0.4743 | val_loss=0.1855 | auc=0.9630 | val_auc=0.9514
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8919 - auc: 0.9618 - loss: 0.4851 - precision: 0.2327 - recall: 0.8925 - val_accuracy: 0.9267 - val_auc: 0.9514 - val_loss: 0.1855 - val_precision: 0.2999 - val_recall: 0.8214 - learning_rate: 0.0010
# Epoch 17/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8933 - auc: 0.9633 - loss: 0.4753 - precision: 0.2358 - recall: 0.8974
# Epoch 17: val_auc did not improve from 0.95136
# Epoch 17 | loss=0.4648 | val_loss=0.1821 | auc=0.9645 | val_auc=0.9506
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8933 - auc: 0.9633 - loss: 0.4753 - precision: 0.2358 - recall: 0.8974 - val_accuracy: 0.9235 - val_auc: 0.9506 - val_loss: 0.1821 - val_precision: 0.2899 - val_recall: 0.8192 - learning_rate: 0.0010
# Epoch 18/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8927 - auc: 0.9644 - loss: 0.4687 - precision: 0.2351 - recall: 0.8995
# Epoch 18: val_auc did not improve from 0.95136
# Epoch 18 | loss=0.4575 | val_loss=0.1804 | auc=0.9656 | val_auc=0.9504
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8927 - auc: 0.9644 - loss: 0.4685 - precision: 0.2351 - recall: 0.8995 - val_accuracy: 0.9271 - val_auc: 0.9504 - val_loss: 0.1804 - val_precision: 0.3007 - val_recall: 0.8175 - learning_rate: 0.0010
# Epoch 19/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8943 - auc: 0.9645 - loss: 0.4671 - precision: 0.2376 - recall: 0.8963
# Epoch 19: val_auc improved from 0.95136 to 0.95144, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 19 | loss=0.4562 | val_loss=0.1640 | auc=0.9658 | val_auc=0.9514
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8944 - auc: 0.9645 - loss: 0.4670 - precision: 0.2376 - recall: 0.8963 - val_accuracy: 0.9359 - val_auc: 0.9514 - val_loss: 0.1640 - val_precision: 0.3303 - val_recall: 0.8093 - learning_rate: 0.0010
# Epoch 20/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8958 - auc: 0.9671 - loss: 0.4494 - precision: 0.2411 - recall: 0.9030
# Epoch 20: val_auc did not improve from 0.95144
# Epoch 20 | loss=0.4412 | val_loss=0.1509 | auc=0.9680 | val_auc=0.9511
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8959 - auc: 0.9671 - loss: 0.4493 - precision: 0.2411 - recall: 0.9030 - val_accuracy: 0.9387 - val_auc: 0.9511 - val_loss: 0.1509 - val_precision: 0.3403 - val_recall: 0.8023 - learning_rate: 0.0010
# Epoch 21/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8959 - auc: 0.9672 - loss: 0.4486 - precision: 0.2418 - recall: 0.9076
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_auc did not improve from 0.95144
# Epoch 21 | loss=0.4351 | val_loss=0.1416 | auc=0.9688 | val_auc=0.9489
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8959 - auc: 0.9673 - loss: 0.4485 - precision: 0.2419 - recall: 0.9076 - val_accuracy: 0.9439 - val_auc: 0.9489 - val_loss: 0.1416 - val_precision: 0.3621 - val_recall: 0.7938 - learning_rate: 0.0010
# Epoch 22/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9034 - auc: 0.9709 - loss: 0.4222 - precision: 0.2570 - recall: 0.9129
# Epoch 22: val_auc did not improve from 0.95144
# Epoch 22 | loss=0.4078 | val_loss=0.1330 | auc=0.9725 | val_auc=0.9482
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9034 - auc: 0.9709 - loss: 0.4222 - precision: 0.2570 - recall: 0.9129 - val_accuracy: 0.9483 - val_auc: 0.9482 - val_loss: 0.1330 - val_precision: 0.3838 - val_recall: 0.7892 - learning_rate: 5.0000e-04
# Epoch 23/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9048 - auc: 0.9720 - loss: 0.4153 - precision: 0.2601 - recall: 0.9140
# Epoch 23: val_auc did not improve from 0.95144
# Epoch 23 | loss=0.4029 | val_loss=0.1311 | auc=0.9732 | val_auc=0.9498
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9048 - auc: 0.9720 - loss: 0.4152 - precision: 0.2601 - recall: 0.9140 - val_accuracy: 0.9477 - val_auc: 0.9498 - val_loss: 0.1311 - val_precision: 0.3802 - val_recall: 0.7875 - learning_rate: 5.0000e-04
# Epoch 24/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9043 - auc: 0.9734 - loss: 0.4036 - precision: 0.2600 - recall: 0.9202
# Epoch 24: val_auc did not improve from 0.95144
# Epoch 24 | loss=0.3944 | val_loss=0.1341 | auc=0.9742 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9043 - auc: 0.9734 - loss: 0.4035 - precision: 0.2600 - recall: 0.9203 - val_accuracy: 0.9473 - val_auc: 0.9513 - val_loss: 0.1341 - val_precision: 0.3785 - val_recall: 0.7897 - learning_rate: 5.0000e-04
# Epoch 25/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9051 - auc: 0.9726 - loss: 0.4102 - precision: 0.2613 - recall: 0.9185
# Epoch 25: val_auc did not improve from 0.95144
# Epoch 25 | loss=0.3954 | val_loss=0.1348 | auc=0.9742 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9051 - auc: 0.9726 - loss: 0.4102 - precision: 0.2613 - recall: 0.9185 - val_accuracy: 0.9456 - val_auc: 0.9502 - val_loss: 0.1348 - val_precision: 0.3705 - val_recall: 0.7953 - learning_rate: 5.0000e-04
# Epoch 26/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9056 - auc: 0.9750 - loss: 0.3901 - precision: 0.2633 - recall: 0.9252
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 26: val_auc did not improve from 0.95144
# Epoch 26 | loss=0.3835 | val_loss=0.1237 | auc=0.9756 | val_auc=0.9503
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9056 - auc: 0.9750 - loss: 0.3901 - precision: 0.2633 - recall: 0.9252 - val_accuracy: 0.9513 - val_auc: 0.9503 - val_loss: 0.1237 - val_precision: 0.4001 - val_recall: 0.7827 - learning_rate: 5.0000e-04
# Epoch 27/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9099 - auc: 0.9760 - loss: 0.3833 - precision: 0.2725 - recall: 0.9243
# Epoch 27: val_auc did not improve from 0.95144
# Epoch 27 | loss=0.3681 | val_loss=0.1204 | auc=0.9775 | val_auc=0.9482
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9099 - auc: 0.9760 - loss: 0.3832 - precision: 0.2725 - recall: 0.9243 - val_accuracy: 0.9517 - val_auc: 0.9482 - val_loss: 0.1204 - val_precision: 0.4024 - val_recall: 0.7858 - learning_rate: 2.5000e-04
# Epoch 28/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9095 - auc: 0.9763 - loss: 0.3803 - precision: 0.2717 - recall: 0.9238
# Epoch 28: val_auc did not improve from 0.95144
# Epoch 28 | loss=0.3684 | val_loss=0.1248 | auc=0.9774 | val_auc=0.9483
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9095 - auc: 0.9763 - loss: 0.3802 - precision: 0.2717 - recall: 0.9238 - val_accuracy: 0.9498 - val_auc: 0.9483 - val_loss: 0.1248 - val_precision: 0.3922 - val_recall: 0.7928 - learning_rate: 2.5000e-04
# Epoch 29/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9103 - auc: 0.9771 - loss: 0.3728 - precision: 0.2738 - recall: 0.9258
# Epoch 29: val_auc did not improve from 0.95144
# Epoch 29 | loss=0.3649 | val_loss=0.1182 | auc=0.9778 | val_auc=0.9484
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9104 - auc: 0.9771 - loss: 0.3727 - precision: 0.2738 - recall: 0.9259 - val_accuracy: 0.9538 - val_auc: 0.9484 - val_loss: 0.1182 - val_precision: 0.4146 - val_recall: 0.7793 - learning_rate: 2.5000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
#
#    ✅ Fold 1 Complete!
#    Val AUC: 0.951947
#    Best epoch: 19
#
# ======================================================================
# 📊 FOLD 2/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7546 - auc: 0.8443 - loss: 0.9344 - precision: 0.1111 - recall: 0.7726
# Epoch 1: val_auc improved from -inf to 0.92336, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 01 | loss=0.8218 | val_loss=0.2824 | auc=0.8839 | val_auc=0.9234
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.7553 - auc: 0.8447 - loss: 0.9332 - precision: 0.1114 - recall: 0.7727 - val_accuracy: 0.8937 - val_auc: 0.9234 - val_loss: 0.2824 - val_precision: 0.2178 - val_recall: 0.7863 - learning_rate: 0.0010
# Epoch 2/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8412 - auc: 0.9173 - loss: 0.7029 - precision: 0.1603 - recall: 0.8272
# Epoch 2: val_auc improved from 0.92336 to 0.93124, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 02 | loss=0.6942 | val_loss=0.2933 | auc=0.9188 | val_auc=0.9312
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8413 - auc: 0.9173 - loss: 0.7029 - precision: 0.1603 - recall: 0.8272 - val_accuracy: 0.8750 - val_auc: 0.9312 - val_loss: 0.2933 - val_precision: 0.1956 - val_recall: 0.8272 - learning_rate: 0.0010
# Epoch 3/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8514 - auc: 0.9281 - loss: 0.6563 - precision: 0.1714 - recall: 0.8386
# Epoch 3: val_auc improved from 0.93124 to 0.93665, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 03 | loss=0.6549 | val_loss=0.2853 | auc=0.9279 | val_auc=0.9366
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8515 - auc: 0.9281 - loss: 0.6563 - precision: 0.1714 - recall: 0.8385 - val_accuracy: 0.8873 - val_auc: 0.9366 - val_loss: 0.2853 - val_precision: 0.2134 - val_recall: 0.8274 - learning_rate: 0.0010
# Epoch 4/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8584 - auc: 0.9345 - loss: 0.6276 - precision: 0.1800 - recall: 0.8498
# Epoch 4: val_auc improved from 0.93665 to 0.93928, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 04 | loss=0.6289 | val_loss=0.2751 | auc=0.9338 | val_auc=0.9393
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8584 - auc: 0.9344 - loss: 0.6276 - precision: 0.1800 - recall: 0.8497 - val_accuracy: 0.8871 - val_auc: 0.9393 - val_loss: 0.2751 - val_precision: 0.2138 - val_recall: 0.8313 - learning_rate: 0.0010
# Epoch 5/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8612 - auc: 0.9389 - loss: 0.6062 - precision: 0.1835 - recall: 0.8527
# Epoch 5: val_auc improved from 0.93928 to 0.94226, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 05 | loss=0.6058 | val_loss=0.2546 | auc=0.9387 | val_auc=0.9423
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8612 - auc: 0.9388 - loss: 0.6062 - precision: 0.1836 - recall: 0.8527 - val_accuracy: 0.8999 - val_auc: 0.9423 - val_loss: 0.2546 - val_precision: 0.2343 - val_recall: 0.8209 - learning_rate: 0.0010
# Epoch 6/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8660 - auc: 0.9430 - loss: 0.5872 - precision: 0.1907 - recall: 0.8642
# Epoch 6: val_auc improved from 0.94226 to 0.94322, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 06 | loss=0.5903 | val_loss=0.2613 | auc=0.9419 | val_auc=0.9432
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8660 - auc: 0.9430 - loss: 0.5872 - precision: 0.1907 - recall: 0.8641 - val_accuracy: 0.8963 - val_auc: 0.9432 - val_loss: 0.2613 - val_precision: 0.2291 - val_recall: 0.8296 - learning_rate: 0.0010
# Epoch 7/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8705 - auc: 0.9472 - loss: 0.5653 - precision: 0.1964 - recall: 0.8655
# Epoch 7: val_auc improved from 0.94322 to 0.94473, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 07 | loss=0.5685 | val_loss=0.2617 | auc=0.9463 | val_auc=0.9447
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8705 - auc: 0.9472 - loss: 0.5654 - precision: 0.1964 - recall: 0.8655 - val_accuracy: 0.8949 - val_auc: 0.9447 - val_loss: 0.2617 - val_precision: 0.2275 - val_recall: 0.8364 - learning_rate: 0.0010
# Epoch 8/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8712 - auc: 0.9490 - loss: 0.5561 - precision: 0.1980 - recall: 0.8700
# Epoch 8: val_auc improved from 0.94473 to 0.94614, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 08 | loss=0.5564 | val_loss=0.2421 | auc=0.9486 | val_auc=0.9461
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8713 - auc: 0.9490 - loss: 0.5561 - precision: 0.1981 - recall: 0.8700 - val_accuracy: 0.9050 - val_auc: 0.9461 - val_loss: 0.2421 - val_precision: 0.2462 - val_recall: 0.8323 - learning_rate: 0.0010
# Epoch 9/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8807 - auc: 0.9519 - loss: 0.5396 - precision: 0.2109 - recall: 0.8712
# Epoch 9: val_auc improved from 0.94614 to 0.94759, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 09 | loss=0.5441 | val_loss=0.2212 | auc=0.9509 | val_auc=0.9476
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8807 - auc: 0.9519 - loss: 0.5396 - precision: 0.2109 - recall: 0.8712 - val_accuracy: 0.9133 - val_auc: 0.9476 - val_loss: 0.2212 - val_precision: 0.2633 - val_recall: 0.8219 - learning_rate: 0.0010
# Epoch 10/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8790 - auc: 0.9542 - loss: 0.5280 - precision: 0.2093 - recall: 0.8763
# Epoch 10: val_auc improved from 0.94759 to 0.94918, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 10 | loss=0.5294 | val_loss=0.2165 | auc=0.9537 | val_auc=0.9492
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8790 - auc: 0.9542 - loss: 0.5280 - precision: 0.2093 - recall: 0.8763 - val_accuracy: 0.9146 - val_auc: 0.9492 - val_loss: 0.2165 - val_precision: 0.2677 - val_recall: 0.8301 - learning_rate: 0.0010
# Epoch 11/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8815 - auc: 0.9567 - loss: 0.5136 - precision: 0.2140 - recall: 0.8846
# Epoch 11: val_auc improved from 0.94918 to 0.95023, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 11 | loss=0.5151 | val_loss=0.2376 | auc=0.9562 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8815 - auc: 0.9567 - loss: 0.5136 - precision: 0.2140 - recall: 0.8846 - val_accuracy: 0.9023 - val_auc: 0.9502 - val_loss: 0.2376 - val_precision: 0.2430 - val_recall: 0.8480 - learning_rate: 0.0010
# Epoch 12/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8843 - auc: 0.9574 - loss: 0.5087 - precision: 0.2179 - recall: 0.8811
# Epoch 12: val_auc improved from 0.95023 to 0.95118, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 12 | loss=0.5098 | val_loss=0.2096 | auc=0.9570 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8843 - auc: 0.9574 - loss: 0.5087 - precision: 0.2179 - recall: 0.8811 - val_accuracy: 0.9129 - val_auc: 0.9512 - val_loss: 0.2096 - val_precision: 0.2643 - val_recall: 0.8354 - learning_rate: 0.0010
# Epoch 13/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8854 - auc: 0.9590 - loss: 0.4998 - precision: 0.2202 - recall: 0.8862
# Epoch 13: val_auc improved from 0.95118 to 0.95175, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 13 | loss=0.4996 | val_loss=0.1912 | auc=0.9587 | val_auc=0.9517
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8854 - auc: 0.9590 - loss: 0.4998 - precision: 0.2202 - recall: 0.8862 - val_accuracy: 0.9261 - val_auc: 0.9517 - val_loss: 0.1912 - val_precision: 0.2976 - val_recall: 0.8180 - learning_rate: 0.0010
# Epoch 14/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8898 - auc: 0.9613 - loss: 0.4858 - precision: 0.2274 - recall: 0.8881
# Epoch 14: val_auc improved from 0.95175 to 0.95198, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 14 | loss=0.4890 | val_loss=0.1957 | auc=0.9605 | val_auc=0.9520
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8898 - auc: 0.9613 - loss: 0.4858 - precision: 0.2274 - recall: 0.8881 - val_accuracy: 0.9194 - val_auc: 0.9520 - val_loss: 0.1957 - val_precision: 0.2806 - val_recall: 0.8333 - learning_rate: 0.0010
# Epoch 15/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8849 - auc: 0.9620 - loss: 0.4812 - precision: 0.2210 - recall: 0.8961
# Epoch 15: val_auc improved from 0.95198 to 0.95222, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 15 | loss=0.4800 | val_loss=0.1913 | auc=0.9620 | val_auc=0.9522
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8850 - auc: 0.9620 - loss: 0.4812 - precision: 0.2210 - recall: 0.8960 - val_accuracy: 0.9230 - val_auc: 0.9522 - val_loss: 0.1913 - val_precision: 0.2894 - val_recall: 0.8250 - learning_rate: 0.0010
# Epoch 16/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8889 - auc: 0.9631 - loss: 0.4745 - precision: 0.2269 - recall: 0.8950
# Epoch 16: val_auc improved from 0.95222 to 0.95264, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 16 | loss=0.4737 | val_loss=0.1713 | auc=0.9630 | val_auc=0.9526
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8889 - auc: 0.9631 - loss: 0.4745 - precision: 0.2269 - recall: 0.8950 - val_accuracy: 0.9292 - val_auc: 0.9526 - val_loss: 0.1713 - val_precision: 0.3079 - val_recall: 0.8197 - learning_rate: 0.0010
# Epoch 17/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8898 - auc: 0.9647 - loss: 0.4645 - precision: 0.2292 - recall: 0.9015
# Epoch 17: val_auc did not improve from 0.95264
# Epoch 17 | loss=0.4662 | val_loss=0.1743 | auc=0.9642 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8898 - auc: 0.9647 - loss: 0.4645 - precision: 0.2292 - recall: 0.9015 - val_accuracy: 0.9344 - val_auc: 0.9512 - val_loss: 0.1743 - val_precision: 0.3244 - val_recall: 0.8086 - learning_rate: 0.0010
# Epoch 18/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8901 - auc: 0.9661 - loss: 0.4548 - precision: 0.2302 - recall: 0.9036
# Epoch 18: val_auc did not improve from 0.95264
# Epoch 18 | loss=0.4567 | val_loss=0.1630 | auc=0.9656 | val_auc=0.9523
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8901 - auc: 0.9661 - loss: 0.4548 - precision: 0.2302 - recall: 0.9036 - val_accuracy: 0.9358 - val_auc: 0.9523 - val_loss: 0.1630 - val_precision: 0.3289 - val_recall: 0.8037 - learning_rate: 0.0010
# Epoch 19/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8952 - auc: 0.9679 - loss: 0.4440 - precision: 0.2394 - recall: 0.9067
# Epoch 19: val_auc did not improve from 0.95264
# Epoch 19 | loss=0.4474 | val_loss=0.1650 | auc=0.9671 | val_auc=0.9526
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8952 - auc: 0.9678 - loss: 0.4440 - precision: 0.2394 - recall: 0.9066 - val_accuracy: 0.9390 - val_auc: 0.9526 - val_loss: 0.1650 - val_precision: 0.3418 - val_recall: 0.8023 - learning_rate: 0.0010
# Epoch 20/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8959 - auc: 0.9689 - loss: 0.4351 - precision: 0.2407 - recall: 0.9070
# Epoch 20: val_auc improved from 0.95264 to 0.95317, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 20 | loss=0.4387 | val_loss=0.1493 | auc=0.9683 | val_auc=0.9532
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8959 - auc: 0.9689 - loss: 0.4351 - precision: 0.2407 - recall: 0.9071 - val_accuracy: 0.9486 - val_auc: 0.9532 - val_loss: 0.1493 - val_precision: 0.3852 - val_recall: 0.7870 - learning_rate: 0.0010
# Epoch 21/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8982 - auc: 0.9692 - loss: 0.4343 - precision: 0.2449 - recall: 0.9073
# Epoch 21: val_auc did not improve from 0.95317
# Epoch 21 | loss=0.4367 | val_loss=0.1447 | auc=0.9687 | val_auc=0.9522
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8982 - auc: 0.9692 - loss: 0.4343 - precision: 0.2449 - recall: 0.9073 - val_accuracy: 0.9482 - val_auc: 0.9522 - val_loss: 0.1447 - val_precision: 0.3824 - val_recall: 0.7805 - learning_rate: 0.0010
# Epoch 22/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8981 - auc: 0.9699 - loss: 0.4291 - precision: 0.2451 - recall: 0.9098
# Epoch 22: val_auc did not improve from 0.95317
# Epoch 22 | loss=0.4321 | val_loss=0.1614 | auc=0.9692 | val_auc=0.9524
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8981 - auc: 0.9699 - loss: 0.4291 - precision: 0.2451 - recall: 0.9098 - val_accuracy: 0.9413 - val_auc: 0.9524 - val_loss: 0.1614 - val_precision: 0.3512 - val_recall: 0.7991 - learning_rate: 0.0010
# Epoch 23/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8974 - auc: 0.9705 - loss: 0.4247 - precision: 0.2443 - recall: 0.9143
# Epoch 23: val_auc improved from 0.95317 to 0.95320, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 23 | loss=0.4247 | val_loss=0.1564 | auc=0.9703 | val_auc=0.9532
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8974 - auc: 0.9705 - loss: 0.4247 - precision: 0.2443 - recall: 0.9143 - val_accuracy: 0.9376 - val_auc: 0.9532 - val_loss: 0.1564 - val_precision: 0.3368 - val_recall: 0.8086 - learning_rate: 0.0010
# Epoch 24/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9004 - auc: 0.9719 - loss: 0.4133 - precision: 0.2504 - recall: 0.9169
# Epoch 24: val_auc did not improve from 0.95320
# Epoch 24 | loss=0.4160 | val_loss=0.1359 | auc=0.9714 | val_auc=0.9524
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9004 - auc: 0.9719 - loss: 0.4133 - precision: 0.2504 - recall: 0.9169 - val_accuracy: 0.9467 - val_auc: 0.9524 - val_loss: 0.1359 - val_precision: 0.3757 - val_recall: 0.7890 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9009 - auc: 0.9722 - loss: 0.4112 - precision: 0.2515 - recall: 0.9172
# Epoch 25: val_auc improved from 0.95320 to 0.95400, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 25 | loss=0.4158 | val_loss=0.1468 | auc=0.9714 | val_auc=0.9540
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9009 - auc: 0.9722 - loss: 0.4112 - precision: 0.2515 - recall: 0.9172 - val_accuracy: 0.9452 - val_auc: 0.9540 - val_loss: 0.1468 - val_precision: 0.3691 - val_recall: 0.8006 - learning_rate: 0.0010
# Epoch 26/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9015 - auc: 0.9726 - loss: 0.4082 - precision: 0.2532 - recall: 0.9208
# Epoch 26: val_auc did not improve from 0.95400
# Epoch 26 | loss=0.4085 | val_loss=0.1398 | auc=0.9724 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9015 - auc: 0.9726 - loss: 0.4082 - precision: 0.2531 - recall: 0.9208 - val_accuracy: 0.9470 - val_auc: 0.9508 - val_loss: 0.1398 - val_precision: 0.3768 - val_recall: 0.7880 - learning_rate: 0.0010
# Epoch 27/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9024 - auc: 0.9736 - loss: 0.4003 - precision: 0.2548 - recall: 0.9199
# Epoch 27: val_auc improved from 0.95400 to 0.95423, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 27 | loss=0.4028 | val_loss=0.1503 | auc=0.9731 | val_auc=0.9542
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9024 - auc: 0.9736 - loss: 0.4003 - precision: 0.2548 - recall: 0.9200 - val_accuracy: 0.9402 - val_auc: 0.9542 - val_loss: 0.1503 - val_precision: 0.3477 - val_recall: 0.8107 - learning_rate: 0.0010
# Epoch 28/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9026 - auc: 0.9734 - loss: 0.4024 - precision: 0.2554 - recall: 0.9206
# Epoch 28: val_auc did not improve from 0.95423
# Epoch 28 | loss=0.4007 | val_loss=0.1348 | auc=0.9735 | val_auc=0.9538
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9026 - auc: 0.9734 - loss: 0.4024 - precision: 0.2554 - recall: 0.9206 - val_accuracy: 0.9493 - val_auc: 0.9538 - val_loss: 0.1348 - val_precision: 0.3898 - val_recall: 0.7926 - learning_rate: 0.0010
# Epoch 29/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9051 - auc: 0.9746 - loss: 0.3931 - precision: 0.2604 - recall: 0.9210
# Epoch 29: val_auc did not improve from 0.95423
# Epoch 29 | loss=0.3938 | val_loss=0.1345 | auc=0.9743 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9051 - auc: 0.9746 - loss: 0.3931 - precision: 0.2604 - recall: 0.9210 - val_accuracy: 0.9490 - val_auc: 0.9513 - val_loss: 0.1345 - val_precision: 0.3877 - val_recall: 0.7892 - learning_rate: 0.0010
# Epoch 30/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9041 - auc: 0.9747 - loss: 0.3913 - precision: 0.2586 - recall: 0.9220
# Epoch 30: val_auc did not improve from 0.95423
# Epoch 30 | loss=0.3926 | val_loss=0.1331 | auc=0.9744 | val_auc=0.9538
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9041 - auc: 0.9747 - loss: 0.3913 - precision: 0.2586 - recall: 0.9220 - val_accuracy: 0.9493 - val_auc: 0.9538 - val_loss: 0.1331 - val_precision: 0.3890 - val_recall: 0.7892 - learning_rate: 0.0010
# Epoch 31/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9059 - auc: 0.9754 - loss: 0.3865 - precision: 0.2629 - recall: 0.9263
# Epoch 31: val_auc did not improve from 0.95423
# Epoch 31 | loss=0.3880 | val_loss=0.1331 | auc=0.9750 | val_auc=0.9533
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9059 - auc: 0.9754 - loss: 0.3865 - precision: 0.2629 - recall: 0.9263 - val_accuracy: 0.9494 - val_auc: 0.9533 - val_loss: 0.1331 - val_precision: 0.3892 - val_recall: 0.7846 - learning_rate: 0.0010
# Epoch 32/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9063 - auc: 0.9760 - loss: 0.3817 - precision: 0.2638 - recall: 0.9264
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_auc did not improve from 0.95423
# Epoch 32 | loss=0.3849 | val_loss=0.1313 | auc=0.9755 | val_auc=0.9514
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9063 - auc: 0.9760 - loss: 0.3818 - precision: 0.2638 - recall: 0.9264 - val_accuracy: 0.9529 - val_auc: 0.9514 - val_loss: 0.1313 - val_precision: 0.4087 - val_recall: 0.7718 - learning_rate: 0.0010
# Epoch 33/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9092 - auc: 0.9775 - loss: 0.3691 - precision: 0.2709 - recall: 0.9326
# Epoch 33: val_auc did not improve from 0.95423
# Epoch 33 | loss=0.3631 | val_loss=0.1136 | auc=0.9780 | val_auc=0.9517
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9092 - auc: 0.9775 - loss: 0.3691 - precision: 0.2709 - recall: 0.9326 - val_accuracy: 0.9598 - val_auc: 0.9517 - val_loss: 0.1136 - val_precision: 0.4555 - val_recall: 0.7633 - learning_rate: 5.0000e-04
# Epoch 34/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9160 - auc: 0.9797 - loss: 0.3501 - precision: 0.2870 - recall: 0.9339
# Epoch 34: val_auc did not improve from 0.95423
# Epoch 34 | loss=0.3477 | val_loss=0.1152 | auc=0.9798 | val_auc=0.9505
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9160 - auc: 0.9797 - loss: 0.3501 - precision: 0.2870 - recall: 0.9339 - val_accuracy: 0.9556 - val_auc: 0.9505 - val_loss: 0.1152 - val_precision: 0.4257 - val_recall: 0.7711 - learning_rate: 5.0000e-04
# Epoch 35/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9124 - auc: 0.9799 - loss: 0.3478 - precision: 0.2789 - recall: 0.9379
# Epoch 35: val_auc did not improve from 0.95423
# Epoch 35 | loss=0.3492 | val_loss=0.1113 | auc=0.9796 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9124 - auc: 0.9799 - loss: 0.3478 - precision: 0.2789 - recall: 0.9379 - val_accuracy: 0.9606 - val_auc: 0.9513 - val_loss: 0.1113 - val_precision: 0.4619 - val_recall: 0.7604 - learning_rate: 5.0000e-04
# Epoch 36/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9150 - auc: 0.9804 - loss: 0.3430 - precision: 0.2848 - recall: 0.9350
# Epoch 36: val_auc did not improve from 0.95423
# Epoch 36 | loss=0.3442 | val_loss=0.1107 | auc=0.9802 | val_auc=0.9517
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9150 - auc: 0.9804 - loss: 0.3431 - precision: 0.2848 - recall: 0.9350 - val_accuracy: 0.9601 - val_auc: 0.9517 - val_loss: 0.1107 - val_precision: 0.4582 - val_recall: 0.7657 - learning_rate: 5.0000e-04
# Epoch 37/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9159 - auc: 0.9805 - loss: 0.3413 - precision: 0.2872 - recall: 0.9369
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_auc did not improve from 0.95423
# Epoch 37 | loss=0.3405 | val_loss=0.1104 | auc=0.9805 | val_auc=0.9518
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9159 - auc: 0.9805 - loss: 0.3413 - precision: 0.2872 - recall: 0.9369 - val_accuracy: 0.9597 - val_auc: 0.9518 - val_loss: 0.1104 - val_precision: 0.4544 - val_recall: 0.7628 - learning_rate: 5.0000e-04
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
#
#    ✅ Fold 2 Complete!
#    Val AUC: 0.955097
#    Best epoch: 27
#
# ======================================================================
# 📊 FOLD 3/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8077 - auc: 0.8337 - loss: 0.9506 - precision: 0.1196 - recall: 0.7024
# Epoch 1: val_auc improved from -inf to 0.91851, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 01 | loss=0.8363 | val_loss=0.2981 | auc=0.8797 | val_auc=0.9185
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.8078 - auc: 0.8338 - loss: 0.9503 - precision: 0.1196 - recall: 0.7025 - val_accuracy: 0.9027 - val_auc: 0.9185 - val_loss: 0.2981 - val_precision: 0.2296 - val_recall: 0.7559 - learning_rate: 0.0010
# Epoch 2/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8512 - auc: 0.9128 - loss: 0.7160 - precision: 0.1660 - recall: 0.8136
# Epoch 2: val_auc improved from 0.91851 to 0.92977, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 02 | loss=0.6997 | val_loss=0.2853 | auc=0.9174 | val_auc=0.9298
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8512 - auc: 0.9129 - loss: 0.7159 - precision: 0.1660 - recall: 0.8136 - val_accuracy: 0.8926 - val_auc: 0.9298 - val_loss: 0.2853 - val_precision: 0.2182 - val_recall: 0.8006 - learning_rate: 0.0010
# Epoch 3/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8594 - auc: 0.9242 - loss: 0.6703 - precision: 0.1759 - recall: 0.8256
# Epoch 3: val_auc improved from 0.92977 to 0.93334, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 03 | loss=0.6570 | val_loss=0.2650 | auc=0.9275 | val_auc=0.9333
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8594 - auc: 0.9242 - loss: 0.6702 - precision: 0.1760 - recall: 0.8257 - val_accuracy: 0.8989 - val_auc: 0.9333 - val_loss: 0.2650 - val_precision: 0.2293 - val_recall: 0.8004 - learning_rate: 0.0010
# Epoch 4/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8620 - auc: 0.9293 - loss: 0.6464 - precision: 0.1799 - recall: 0.8329
# Epoch 4: val_auc improved from 0.93334 to 0.93713, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 04 | loss=0.6359 | val_loss=0.2831 | auc=0.9321 | val_auc=0.9371
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8620 - auc: 0.9294 - loss: 0.6464 - precision: 0.1799 - recall: 0.8329 - val_accuracy: 0.8896 - val_auc: 0.9371 - val_loss: 0.2831 - val_precision: 0.2161 - val_recall: 0.8202 - learning_rate: 0.0010
# Epoch 5/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8675 - auc: 0.9348 - loss: 0.6224 - precision: 0.1874 - recall: 0.8417
# Epoch 5: val_auc improved from 0.93713 to 0.93931, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 05 | loss=0.6139 | val_loss=0.2551 | auc=0.9371 | val_auc=0.9393
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8675 - auc: 0.9349 - loss: 0.6224 - precision: 0.1874 - recall: 0.8417 - val_accuracy: 0.9000 - val_auc: 0.9393 - val_loss: 0.2551 - val_precision: 0.2336 - val_recall: 0.8147 - learning_rate: 0.0010
# Epoch 6/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8713 - auc: 0.9393 - loss: 0.6019 - precision: 0.1933 - recall: 0.8501
# Epoch 6: val_auc improved from 0.93931 to 0.94186, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 06 | loss=0.5917 | val_loss=0.2255 | auc=0.9418 | val_auc=0.9419
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8713 - auc: 0.9393 - loss: 0.6018 - precision: 0.1933 - recall: 0.8501 - val_accuracy: 0.9096 - val_auc: 0.9419 - val_loss: 0.2255 - val_precision: 0.2528 - val_recall: 0.8103 - learning_rate: 0.0010
# Epoch 7/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8736 - auc: 0.9426 - loss: 0.5859 - precision: 0.1971 - recall: 0.8567
# Epoch 7: val_auc improved from 0.94186 to 0.94376, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 07 | loss=0.5755 | val_loss=0.2309 | auc=0.9450 | val_auc=0.9438
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8736 - auc: 0.9427 - loss: 0.5858 - precision: 0.1971 - recall: 0.8568 - val_accuracy: 0.9144 - val_auc: 0.9438 - val_loss: 0.2309 - val_precision: 0.2646 - val_recall: 0.8125 - learning_rate: 0.0010
# Epoch 8/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8752 - auc: 0.9447 - loss: 0.5752 - precision: 0.1996 - recall: 0.8593
# Epoch 8: val_auc improved from 0.94376 to 0.94558, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 08 | loss=0.5622 | val_loss=0.2327 | auc=0.9476 | val_auc=0.9456
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8752 - auc: 0.9447 - loss: 0.5752 - precision: 0.1996 - recall: 0.8593 - val_accuracy: 0.9060 - val_auc: 0.9456 - val_loss: 0.2327 - val_precision: 0.2481 - val_recall: 0.8309 - learning_rate: 0.0010
# Epoch 9/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8760 - auc: 0.9479 - loss: 0.5594 - precision: 0.2017 - recall: 0.8665
# Epoch 9: val_auc improved from 0.94558 to 0.94649, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 09 | loss=0.5493 | val_loss=0.2122 | auc=0.9500 | val_auc=0.9465
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8760 - auc: 0.9479 - loss: 0.5593 - precision: 0.2017 - recall: 0.8665 - val_accuracy: 0.9206 - val_auc: 0.9465 - val_loss: 0.2122 - val_precision: 0.2803 - val_recall: 0.8098 - learning_rate: 0.0010
# Epoch 10/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8867 - auc: 0.9521 - loss: 0.5357 - precision: 0.2173 - recall: 0.8676
# Epoch 10: val_auc improved from 0.94649 to 0.94701, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 10 | loss=0.5302 | val_loss=0.2177 | auc=0.9534 | val_auc=0.9470
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8867 - auc: 0.9521 - loss: 0.5357 - precision: 0.2173 - recall: 0.8677 - val_accuracy: 0.9183 - val_auc: 0.9470 - val_loss: 0.2177 - val_precision: 0.2754 - val_recall: 0.8193 - learning_rate: 0.0010
# Epoch 11/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8832 - auc: 0.9531 - loss: 0.5310 - precision: 0.2130 - recall: 0.8746
# Epoch 11: val_auc improved from 0.94701 to 0.94823, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 11 | loss=0.5223 | val_loss=0.2005 | auc=0.9549 | val_auc=0.9482
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8832 - auc: 0.9532 - loss: 0.5310 - precision: 0.2130 - recall: 0.8746 - val_accuracy: 0.9265 - val_auc: 0.9482 - val_loss: 0.2005 - val_precision: 0.2976 - val_recall: 0.8096 - learning_rate: 0.0010
# Epoch 12/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8880 - auc: 0.9557 - loss: 0.5160 - precision: 0.2205 - recall: 0.8754
# Epoch 12: val_auc improved from 0.94823 to 0.94955, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 12 | loss=0.5102 | val_loss=0.1908 | auc=0.9570 | val_auc=0.9495
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8880 - auc: 0.9558 - loss: 0.5159 - precision: 0.2206 - recall: 0.8755 - val_accuracy: 0.9291 - val_auc: 0.9495 - val_loss: 0.1908 - val_precision: 0.3057 - val_recall: 0.8069 - learning_rate: 0.0010
# Epoch 13/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8866 - auc: 0.9566 - loss: 0.5104 - precision: 0.2188 - recall: 0.8786
# Epoch 13: val_auc improved from 0.94955 to 0.94956, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 13 | loss=0.5037 | val_loss=0.1920 | auc=0.9580 | val_auc=0.9496
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8866 - auc: 0.9566 - loss: 0.5104 - precision: 0.2188 - recall: 0.8786 - val_accuracy: 0.9226 - val_auc: 0.9496 - val_loss: 0.1920 - val_precision: 0.2873 - val_recall: 0.8188 - learning_rate: 0.0010
# Epoch 14/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8855 - auc: 0.9592 - loss: 0.4959 - precision: 0.2183 - recall: 0.8873
# Epoch 14: val_auc did not improve from 0.94956
# Epoch 14 | loss=0.4912 | val_loss=0.1839 | auc=0.9602 | val_auc=0.9484
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8855 - auc: 0.9592 - loss: 0.4959 - precision: 0.2183 - recall: 0.8873 - val_accuracy: 0.9304 - val_auc: 0.9484 - val_loss: 0.1839 - val_precision: 0.3099 - val_recall: 0.8050 - learning_rate: 0.0010
# Epoch 15/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8903 - auc: 0.9609 - loss: 0.4867 - precision: 0.2261 - recall: 0.8893
# Epoch 15: val_auc improved from 0.94956 to 0.95010, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# ...
# Epoch 4: val_auc improved from 0.93646 to 0.93855, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 04 | loss=0.6202 | val_loss=0.2545 | auc=0.9359 | val_auc=0.9386
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8695 - auc: 0.9331 - loss: 0.6307 - precision: 0.1894 - recall: 0.8376 - val_accuracy: 0.9027 - val_auc: 0.9386 - val_loss: 0.2545 - val_precision: 0.2384 - val_recall: 0.8118 - learning_rate: 0.0010
# Epoch 5/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8726 - auc: 0.9373 - loss: 0.6098 - precision: 0.1938 - recall: 0.8413
# Epoch 5: val_auc improved from 0.93855 to 0.93989, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 05 | loss=0.5994 | val_loss=0.2321 | auc=0.9401 | val_auc=0.9399
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8726 - auc: 0.9373 - loss: 0.6098 - precision: 0.1938 - recall: 0.8413 - val_accuracy: 0.9103 - val_auc: 0.9399 - val_loss: 0.2321 - val_precision: 0.2543 - val_recall: 0.8084 - learning_rate: 0.0010
# Epoch 6/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8754 - auc: 0.9425 - loss: 0.5857 - precision: 0.1990 - recall: 0.8523
# Epoch 6: val_auc improved from 0.93989 to 0.94223, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 06 | loss=0.5791 | val_loss=0.2330 | auc=0.9443 | val_auc=0.9422
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8754 - auc: 0.9425 - loss: 0.5856 - precision: 0.1989 - recall: 0.8524 - val_accuracy: 0.9055 - val_auc: 0.9422 - val_loss: 0.2330 - val_precision: 0.2460 - val_recall: 0.8234 - learning_rate: 0.0010
# Epoch 7/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8772 - auc: 0.9452 - loss: 0.5729 - precision: 0.2023 - recall: 0.8587
# Epoch 7: val_auc improved from 0.94223 to 0.94368, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 07 | loss=0.5624 | val_loss=0.2296 | auc=0.9476 | val_auc=0.9437
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8772 - auc: 0.9453 - loss: 0.5728 - precision: 0.2023 - recall: 0.8588 - val_accuracy: 0.9145 - val_auc: 0.9437 - val_loss: 0.2296 - val_precision: 0.2660 - val_recall: 0.8202 - learning_rate: 0.0010
# Epoch 8/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8797 - auc: 0.9482 - loss: 0.5582 - precision: 0.2066 - recall: 0.8643
# Epoch 8: val_auc improved from 0.94368 to 0.94499, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 08 | loss=0.5507 | val_loss=0.2472 | auc=0.9498 | val_auc=0.9450
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8797 - auc: 0.9482 - loss: 0.5581 - precision: 0.2066 - recall: 0.8644 - val_accuracy: 0.8944 - val_auc: 0.9450 - val_loss: 0.2472 - val_precision: 0.2275 - val_recall: 0.8418 - learning_rate: 0.0010
# Epoch 9/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8807 - auc: 0.9512 - loss: 0.5420 - precision: 0.2090 - recall: 0.8717
# Epoch 9: val_auc improved from 0.94499 to 0.94602, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 09 | loss=0.5346 | val_loss=0.2221 | auc=0.9527 | val_auc=0.9460
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8807 - auc: 0.9512 - loss: 0.5420 - precision: 0.2090 - recall: 0.8717 - val_accuracy: 0.9159 - val_auc: 0.9460 - val_loss: 0.2221 - val_precision: 0.2693 - val_recall: 0.8195 - learning_rate: 0.0010
# Epoch 10/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8832 - auc: 0.9526 - loss: 0.5342 - precision: 0.2127 - recall: 0.8713
# Epoch 10: val_auc improved from 0.94602 to 0.94799, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 10 | loss=0.5261 | val_loss=0.2001 | auc=0.9543 | val_auc=0.9480
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8832 - auc: 0.9526 - loss: 0.5341 - precision: 0.2127 - recall: 0.8713 - val_accuracy: 0.9247 - val_auc: 0.9480 - val_loss: 0.2001 - val_precision: 0.2929 - val_recall: 0.8149 - learning_rate: 0.0010
# Epoch 11/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8890 - auc: 0.9551 - loss: 0.5200 - precision: 0.2219 - recall: 0.8728
# Epoch 11: val_auc improved from 0.94799 to 0.94855, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 11 | loss=0.5145 | val_loss=0.1986 | auc=0.9563 | val_auc=0.9485
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8890 - auc: 0.9551 - loss: 0.5200 - precision: 0.2219 - recall: 0.8728 - val_accuracy: 0.9275 - val_auc: 0.9485 - val_loss: 0.1986 - val_precision: 0.3004 - val_recall: 0.8072 - learning_rate: 0.0010
# Epoch 12/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8904 - auc: 0.9576 - loss: 0.5049 - precision: 0.2253 - recall: 0.8812
# Epoch 12: val_auc improved from 0.94855 to 0.94915, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 12 | loss=0.5013 | val_loss=0.1952 | auc=0.9585 | val_auc=0.9492
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8903 - auc: 0.9577 - loss: 0.5049 - precision: 0.2253 - recall: 0.8812 - val_accuracy: 0.9225 - val_auc: 0.9492 - val_loss: 0.1952 - val_precision: 0.2869 - val_recall: 0.8178 - learning_rate: 0.0010
# Epoch 13/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8896 - auc: 0.9578 - loss: 0.5046 - precision: 0.2239 - recall: 0.8807
# Epoch 13: val_auc improved from 0.94915 to 0.94957, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 13 | loss=0.4948 | val_loss=0.1992 | auc=0.9597 | val_auc=0.9496
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8896 - auc: 0.9579 - loss: 0.5045 - precision: 0.2239 - recall: 0.8808 - val_accuracy: 0.9235 - val_auc: 0.9496 - val_loss: 0.1992 - val_precision: 0.2906 - val_recall: 0.8222 - learning_rate: 0.0010
# Epoch 14/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8934 - auc: 0.9597 - loss: 0.4933 - precision: 0.2306 - recall: 0.8836
# Epoch 14: val_auc did not improve from 0.94957
# Epoch 14 | loss=0.4817 | val_loss=0.1834 | auc=0.9618 | val_auc=0.9489
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8933 - auc: 0.9597 - loss: 0.4931 - precision: 0.2306 - recall: 0.8837 - val_accuracy: 0.9272 - val_auc: 0.9489 - val_loss: 0.1834 - val_precision: 0.3008 - val_recall: 0.8171 - learning_rate: 0.0010
# Epoch 15/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8921 - auc: 0.9613 - loss: 0.4827 - precision: 0.2295 - recall: 0.8905
# Epoch 15: val_auc did not improve from 0.94957
# Epoch 15 | loss=0.4779 | val_loss=0.1816 | auc=0.9623 | val_auc=0.9489
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8921 - auc: 0.9613 - loss: 0.4827 - precision: 0.2295 - recall: 0.8905 - val_accuracy: 0.9308 - val_auc: 0.9489 - val_loss: 0.1816 - val_precision: 0.3113 - val_recall: 0.8060 - learning_rate: 0.0010
# Epoch 16/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8942 - auc: 0.9632 - loss: 0.4723 - precision: 0.2333 - recall: 0.8921
# Epoch 16: val_auc did not improve from 0.94957
# Epoch 16 | loss=0.4665 | val_loss=0.1799 | auc=0.9643 | val_auc=0.9490
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8942 - auc: 0.9632 - loss: 0.4723 - precision: 0.2333 - recall: 0.8921 - val_accuracy: 0.9291 - val_auc: 0.9490 - val_loss: 0.1799 - val_precision: 0.3069 - val_recall: 0.8151 - learning_rate: 0.0010
# Epoch 17/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8944 - auc: 0.9627 - loss: 0.4746 - precision: 0.2334 - recall: 0.8901
# Epoch 17: val_auc improved from 0.94957 to 0.95092, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 17 | loss=0.4652 | val_loss=0.1833 | auc=0.9643 | val_auc=0.9509
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8944 - auc: 0.9627 - loss: 0.4745 - precision: 0.2334 - recall: 0.8901 - val_accuracy: 0.9270 - val_auc: 0.9509 - val_loss: 0.1833 - val_precision: 0.3015 - val_recall: 0.8251 - learning_rate: 0.0010
# Epoch 18/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8966 - auc: 0.9662 - loss: 0.4521 - precision: 0.2391 - recall: 0.9024
# Epoch 18: val_auc improved from 0.95092 to 0.95143, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 18 | loss=0.4514 | val_loss=0.1768 | auc=0.9664 | val_auc=0.9514
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8966 - auc: 0.9662 - loss: 0.4520 - precision: 0.2391 - recall: 0.9024 - val_accuracy: 0.9310 - val_auc: 0.9514 - val_loss: 0.1768 - val_precision: 0.3138 - val_recall: 0.8200 - learning_rate: 0.0010
# Epoch 19/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8964 - auc: 0.9668 - loss: 0.4487 - precision: 0.2390 - recall: 0.9047
# Epoch 19: val_auc did not improve from 0.95143
# Epoch 19 | loss=0.4461 | val_loss=0.1771 | auc=0.9672 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8964 - auc: 0.9668 - loss: 0.4487 - precision: 0.2390 - recall: 0.9047 - val_accuracy: 0.9299 - val_auc: 0.9502 - val_loss: 0.1771 - val_precision: 0.3101 - val_recall: 0.8193 - learning_rate: 0.0010
# Epoch 20/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8945 - auc: 0.9662 - loss: 0.4516 - precision: 0.2356 - recall: 0.9043
# Epoch 20: val_auc improved from 0.95143 to 0.95182, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 20 | loss=0.4463 | val_loss=0.1628 | auc=0.9672 | val_auc=0.9518
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8945 - auc: 0.9662 - loss: 0.4516 - precision: 0.2356 - recall: 0.9043 - val_accuracy: 0.9371 - val_auc: 0.9518 - val_loss: 0.1628 - val_precision: 0.3358 - val_recall: 0.8151 - learning_rate: 0.0010
# Epoch 21/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8972 - auc: 0.9676 - loss: 0.4426 - precision: 0.2399 - recall: 0.9007
# Epoch 21: val_auc did not improve from 0.95182
# Epoch 21 | loss=0.4363 | val_loss=0.1663 | auc=0.9687 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8972 - auc: 0.9676 - loss: 0.4426 - precision: 0.2399 - recall: 0.9008 - val_accuracy: 0.9342 - val_auc: 0.9502 - val_loss: 0.1663 - val_precision: 0.3244 - val_recall: 0.8137 - learning_rate: 0.0010
# Epoch 22/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8991 - auc: 0.9679 - loss: 0.4402 - precision: 0.2438 - recall: 0.9039
# Epoch 22: val_auc did not improve from 0.95182
# Epoch 22 | loss=0.4305 | val_loss=0.1652 | auc=0.9694 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8991 - auc: 0.9679 - loss: 0.4401 - precision: 0.2438 - recall: 0.9039 - val_accuracy: 0.9370 - val_auc: 0.9513 - val_loss: 0.1652 - val_precision: 0.3346 - val_recall: 0.8101 - learning_rate: 0.0010
# Epoch 23/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9001 - auc: 0.9693 - loss: 0.4305 - precision: 0.2462 - recall: 0.9072
# Epoch 23: val_auc did not improve from 0.95182
# Epoch 23 | loss=0.4247 | val_loss=0.1560 | auc=0.9702 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9001 - auc: 0.9693 - loss: 0.4304 - precision: 0.2462 - recall: 0.9073 - val_accuracy: 0.9386 - val_auc: 0.9502 - val_loss: 0.1560 - val_precision: 0.3404 - val_recall: 0.8035 - learning_rate: 0.0010
# Epoch 24/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8985 - auc: 0.9697 - loss: 0.4273 - precision: 0.2438 - recall: 0.9116
# Epoch 24: val_auc did not improve from 0.95182
# Epoch 24 | loss=0.4204 | val_loss=0.1444 | auc=0.9708 | val_auc=0.9504
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8985 - auc: 0.9697 - loss: 0.4272 - precision: 0.2438 - recall: 0.9116 - val_accuracy: 0.9409 - val_auc: 0.9504 - val_loss: 0.1444 - val_precision: 0.3494 - val_recall: 0.8001 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8986 - auc: 0.9711 - loss: 0.4168 - precision: 0.2442 - recall: 0.9132
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: val_auc did not improve from 0.95182
# Epoch 25 | loss=0.4152 | val_loss=0.1519 | auc=0.9715 | val_auc=0.9505
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8986 - auc: 0.9711 - loss: 0.4168 - precision: 0.2442 - recall: 0.9132 - val_accuracy: 0.9422 - val_auc: 0.9505 - val_loss: 0.1519 - val_precision: 0.3546 - val_recall: 0.7934 - learning_rate: 0.0010
# Epoch 26/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9052 - auc: 0.9737 - loss: 0.3979 - precision: 0.2578 - recall: 0.9162
# Epoch 26: val_auc did not improve from 0.95182
# Epoch 26 | loss=0.3873 | val_loss=0.1367 | auc=0.9752 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9053 - auc: 0.9737 - loss: 0.3978 - precision: 0.2578 - recall: 0.9162 - val_accuracy: 0.9464 - val_auc: 0.9513 - val_loss: 0.1367 - val_precision: 0.3749 - val_recall: 0.7951 - learning_rate: 5.0000e-04
# Epoch 27/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9065 - auc: 0.9744 - loss: 0.3928 - precision: 0.2616 - recall: 0.9262
# Epoch 27: val_auc did not improve from 0.95182
# Epoch 27 | loss=0.3799 | val_loss=0.1329 | auc=0.9760 | val_auc=0.9495
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9065 - auc: 0.9744 - loss: 0.3927 - precision: 0.2617 - recall: 0.9262 - val_accuracy: 0.9480 - val_auc: 0.9495 - val_loss: 0.1329 - val_precision: 0.3825 - val_recall: 0.7905 - learning_rate: 5.0000e-04
# Epoch 28/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9074 - auc: 0.9762 - loss: 0.3771 - precision: 0.2636 - recall: 0.9256
# Epoch 28: val_auc did not improve from 0.95182
# Epoch 28 | loss=0.3712 | val_loss=0.1332 | auc=0.9770 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9074 - auc: 0.9762 - loss: 0.3770 - precision: 0.2636 - recall: 0.9256 - val_accuracy: 0.9471 - val_auc: 0.9512 - val_loss: 0.1332 - val_precision: 0.3782 - val_recall: 0.7968 - learning_rate: 5.0000e-04
# Epoch 29/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9095 - auc: 0.9759 - loss: 0.3812 - precision: 0.2682 - recall: 0.9257
# Epoch 29: val_auc did not improve from 0.95182
# Epoch 29 | loss=0.3727 | val_loss=0.1299 | auc=0.9770 | val_auc=0.9511
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9095 - auc: 0.9759 - loss: 0.3812 - precision: 0.2682 - recall: 0.9257 - val_accuracy: 0.9481 - val_auc: 0.9511 - val_loss: 0.1299 - val_precision: 0.3836 - val_recall: 0.7939 - learning_rate: 5.0000e-04
# Epoch 30/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9093 - auc: 0.9773 - loss: 0.3680 - precision: 0.2682 - recall: 0.9298
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 30: val_auc did not improve from 0.95182
# Epoch 30 | loss=0.3649 | val_loss=0.1369 | auc=0.9779 | val_auc=0.9513
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9093 - auc: 0.9773 - loss: 0.3680 - precision: 0.2683 - recall: 0.9298 - val_accuracy: 0.9452 - val_auc: 0.9513 - val_loss: 0.1369 - val_precision: 0.3700 - val_recall: 0.8076 - learning_rate: 5.0000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
#
#    ✅ Fold 5 Complete!
#    Val AUC: 0.952465
#    Best epoch: 20
#
# ======================================================================
# 📊 CROSS-VALIDATION RESULTS
# ======================================================================
#
# Fold AUC Scores:
#    Fold 1: 0.951947
#    Fold 2: 0.955097
#    Fold 3: 0.955868
#    Fold 4: 0.956232
#    Fold 5: 0.952465
#
# 🏆 Summary:
#    Mean AUC: 0.954322
#    Std AUC:  0.001773
#    Min AUC:  0.951947
#    Max AUC:  0.956232
#
# ✅ CV results saved to: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/results/cv_results.json

# %%
print("\n" + "="*70)
print("🎯 TRAINING FINAL MODEL ON FULL DATASET")
print("="*70)

# Rebuild model
final_model = build_dual_path_model(len(GNN_FEATURES), len(TABNET_FEATURES))
final_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=CONFIG['learning_rate']),
    loss='binary_crossentropy',
    metrics=['accuracy', keras.metrics.AUC(name='auc'),
            keras.metrics.Precision(name='precision'),
            keras.metrics.Recall(name='recall')]
)

# Use 80/20 split for final training
from sklearn.model_selection import train_test_split

X_gnn_train, X_gnn_val, X_tabnet_train, X_tabnet_val, y_train_final, y_val_final = train_test_split(
    X_gnn_scaled, X_tabnet_scaled, y,
    test_size=0.2,
    stratify=y,
    random_state=SEED
)

print(f"   Training samples: {len(y_train_final):,}")
print(f"   Validation samples: {len(y_val_final):,}")

# Callbacks for final model
final_callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_auc',
        patience=CONFIG['patience'],
        restore_best_weights=True,
        mode='max',
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_auc',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        mode='max',
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=str(MODEL_DIR / 'final_model_best.h5'),
        monitor='val_auc',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    keras.callbacks.CSVLogger(
        filename=str(RESULTS_DIR / 'training_log.csv')
    )
]

print("\n🎓 Training final model...")
final_history = final_model.fit(
    [X_gnn_train, X_tabnet_train],
    y_train_final,
    validation_data=([X_gnn_val, X_tabnet_val], y_val_final),
    epochs=CONFIG['epochs'],
    batch_size=CONFIG['batch_size'],
    class_weight=class_weight if CONFIG['use_class_weights'] else None,
    callbacks=final_callbacks,
    verbose=1
)

print("\n✅ Final model training complete!")

# Save final model
final_model.save(MODEL_DIR / 'final_model.h5')
print(f"✅ Final model saved: {MODEL_DIR / 'final_model.h5'}")
# Out:
# ======================================================================
# 🎯 TRAINING FINAL MODEL ON FULL DATASET
# ======================================================================
#    Training samples: 472,432
#    Validation samples: 118,108
#
# 🎓 Training final model...
# Epoch 1/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7557 - auc: 0.8265 - loss: 0.9733 - precision: 0.1054 - recall: 0.7418
# Epoch 1: val_auc improved from -inf to 0.92227, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.7564 - auc: 0.8271 - loss: 0.9716 - precision: 0.1057 - recall: 0.7423 - val_accuracy: 0.9084 - val_auc: 0.9223 - val_loss: 0.3107 - val_precision: 0.2416 - val_recall: 0.7566 - learning_rate: 0.0010
# Epoch 2/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8531 - auc: 0.9144 - loss: 0.7112 - precision: 0.1678 - recall: 0.8107
# Epoch 2: val_auc improved from 0.92227 to 0.93063, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8531 - auc: 0.9144 - loss: 0.7111 - precision: 0.1678 - recall: 0.8108 - val_accuracy: 0.8579 - val_auc: 0.9306 - val_loss: 0.3459 - val_precision: 0.1772 - val_recall: 0.8396 - learning_rate: 0.0010
# Epoch 3/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8658 - auc: 0.9259 - loss: 0.6630 - precision: 0.1831 - recall: 0.8214
# Epoch 3: val_auc improved from 0.93063 to 0.93603, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8658 - auc: 0.9259 - loss: 0.6630 - precision: 0.1830 - recall: 0.8215 - val_accuracy: 0.8622 - val_auc: 0.9360 - val_loss: 0.3182 - val_precision: 0.1835 - val_recall: 0.8514 - learning_rate: 0.0010
# Epoch 4/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8679 - auc: 0.9329 - loss: 0.6322 - precision: 0.1881 - recall: 0.8396
# Epoch 4: val_auc improved from 0.93603 to 0.93913, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8679 - auc: 0.9329 - loss: 0.6322 - precision: 0.1881 - recall: 0.8396 - val_accuracy: 0.8720 - val_auc: 0.9391 - val_loss: 0.3047 - val_precision: 0.1952 - val_recall: 0.8505 - learning_rate: 0.0010
# Epoch 5/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8761 - auc: 0.9376 - loss: 0.6108 - precision: 0.1986 - recall: 0.8402
# Epoch 5: val_auc improved from 0.93913 to 0.94130, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8761 - auc: 0.9376 - loss: 0.6108 - precision: 0.1986 - recall: 0.8402 - val_accuracy: 0.8875 - val_auc: 0.9413 - val_loss: 0.2813 - val_precision: 0.2159 - val_recall: 0.8413 - learning_rate: 0.0010
# Epoch 6/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8801 - auc: 0.9422 - loss: 0.5876 - precision: 0.2054 - recall: 0.8491
# Epoch 6: val_auc improved from 0.94130 to 0.94446, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8801 - auc: 0.9422 - loss: 0.5876 - precision: 0.2054 - recall: 0.8491 - val_accuracy: 0.9042 - val_auc: 0.9445 - val_loss: 0.2464 - val_precision: 0.2447 - val_recall: 0.8331 - learning_rate: 0.0010
# Epoch 7/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8835 - auc: 0.9458 - loss: 0.5698 - precision: 0.2111 - recall: 0.8541
# Epoch 7: val_auc improved from 0.94446 to 0.94555, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8835 - auc: 0.9458 - loss: 0.5698 - precision: 0.2110 - recall: 0.8542 - val_accuracy: 0.9031 - val_auc: 0.9456 - val_loss: 0.2492 - val_precision: 0.2431 - val_recall: 0.8367 - learning_rate: 0.0010
# Epoch 8/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8879 - auc: 0.9482 - loss: 0.5575 - precision: 0.2187 - recall: 0.8589
# Epoch 8: val_auc improved from 0.94555 to 0.94670, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8878 - auc: 0.9482 - loss: 0.5575 - precision: 0.2186 - recall: 0.8590 - val_accuracy: 0.9125 - val_auc: 0.9467 - val_loss: 0.2275 - val_precision: 0.2618 - val_recall: 0.8239 - learning_rate: 0.0010
# Epoch 9/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8859 - auc: 0.9505 - loss: 0.5458 - precision: 0.2159 - recall: 0.8621
# Epoch 9: val_auc improved from 0.94670 to 0.94730, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8858 - auc: 0.9505 - loss: 0.5458 - precision: 0.2158 - recall: 0.8622 - val_accuracy: 0.9125 - val_auc: 0.9473 - val_loss: 0.2135 - val_precision: 0.2623 - val_recall: 0.8272 - learning_rate: 0.0010
# Epoch 10/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8855 - auc: 0.9542 - loss: 0.5257 - precision: 0.2169 - recall: 0.8735
# Epoch 10: val_auc improved from 0.94730 to 0.94865, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8855 - auc: 0.9542 - loss: 0.5257 - precision: 0.2169 - recall: 0.8735 - val_accuracy: 0.9075 - val_auc: 0.9487 - val_loss: 0.2248 - val_precision: 0.2521 - val_recall: 0.8352 - learning_rate: 0.0010
# Epoch 11/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8888 - auc: 0.9564 - loss: 0.5128 - precision: 0.2228 - recall: 0.8788
# Epoch 11: val_auc improved from 0.94865 to 0.95008, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.8888 - auc: 0.9564 - loss: 0.5128 - precision: 0.2228 - recall: 0.8788 - val_accuracy: 0.9106 - val_auc: 0.9501 - val_loss: 0.2201 - val_precision: 0.2591 - val_recall: 0.8357 - learning_rate: 0.0010
# Epoch 12/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8879 - auc: 0.9573 - loss: 0.5079 - precision: 0.2219 - recall: 0.8831
# Epoch 12: val_auc improved from 0.95008 to 0.95145, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8878 - auc: 0.9573 - loss: 0.5079 - precision: 0.2219 - recall: 0.8831 - val_accuracy: 0.9222 - val_auc: 0.9515 - val_loss: 0.2013 - val_precision: 0.2873 - val_recall: 0.8263 - learning_rate: 0.0010
# Epoch 13/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8937 - auc: 0.9597 - loss: 0.4943 - precision: 0.2318 - recall: 0.8840
# Epoch 13: val_auc did not improve from 0.95145
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8937 - auc: 0.9597 - loss: 0.4943 - precision: 0.2318 - recall: 0.8840 - val_accuracy: 0.9219 - val_auc: 0.9513 - val_loss: 0.2024 - val_precision: 0.2861 - val_recall: 0.8239 - learning_rate: 0.0010
# Epoch 14/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8938 - auc: 0.9598 - loss: 0.4946 - precision: 0.2318 - recall: 0.8832
# Epoch 14: val_auc did not improve from 0.95145
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8937 - auc: 0.9598 - loss: 0.4946 - precision: 0.2318 - recall: 0.8832 - val_accuracy: 0.9285 - val_auc: 0.9497 - val_loss: 0.1857 - val_precision: 0.3044 - val_recall: 0.8105 - learning_rate: 0.0010
# Epoch 15/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8956 - auc: 0.9617 - loss: 0.4813 - precision: 0.2357 - recall: 0.8880
# Epoch 15: val_auc did not improve from 0.95145
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8956 - auc: 0.9617 - loss: 0.4813 - precision: 0.2356 - recall: 0.8880 - val_accuracy: 0.9308 - val_auc: 0.9499 - val_loss: 0.1760 - val_precision: 0.3118 - val_recall: 0.8105 - learning_rate: 0.0010
# Epoch 16/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8974 - auc: 0.9625 - loss: 0.4763 - precision: 0.2388 - recall: 0.8873
# Epoch 16: val_auc did not improve from 0.95145
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8974 - auc: 0.9625 - loss: 0.4763 - precision: 0.2388 - recall: 0.8873 - val_accuracy: 0.9263 - val_auc: 0.9489 - val_loss: 0.1797 - val_precision: 0.2983 - val_recall: 0.8178 - learning_rate: 0.0010
# Epoch 17/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8971 - auc: 0.9638 - loss: 0.4684 - precision: 0.2388 - recall: 0.8912
# Epoch 17: val_auc improved from 0.95145 to 0.95161, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8971 - auc: 0.9639 - loss: 0.4684 - precision: 0.2388 - recall: 0.8912 - val_accuracy: 0.9325 - val_auc: 0.9516 - val_loss: 0.1770 - val_precision: 0.3188 - val_recall: 0.8161 - learning_rate: 0.0010
# Epoch 18/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9003 - auc: 0.9660 - loss: 0.4535 - precision: 0.2456 - recall: 0.8954
# Epoch 18: val_auc improved from 0.95161 to 0.95275, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9003 - auc: 0.9660 - loss: 0.4535 - precision: 0.2456 - recall: 0.8955 - val_accuracy: 0.9353 - val_auc: 0.9527 - val_loss: 0.1693 - val_precision: 0.3270 - val_recall: 0.8021 - learning_rate: 0.0010
# Epoch 19/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9009 - auc: 0.9675 - loss: 0.4446 - precision: 0.2478 - recall: 0.9030
# Epoch 19: val_auc did not improve from 0.95275
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9009 - auc: 0.9675 - loss: 0.4447 - precision: 0.2477 - recall: 0.9030 - val_accuracy: 0.9359 - val_auc: 0.9502 - val_loss: 0.1590 - val_precision: 0.3299 - val_recall: 0.8074 - learning_rate: 0.0010
# Epoch 20/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8977 - auc: 0.9678 - loss: 0.4419 - precision: 0.2420 - recall: 0.9049
# Epoch 20: val_auc did not improve from 0.95275
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8977 - auc: 0.9678 - loss: 0.4419 - precision: 0.2420 - recall: 0.9049 - val_accuracy: 0.9328 - val_auc: 0.9512 - val_loss: 0.1708 - val_precision: 0.3184 - val_recall: 0.8076 - learning_rate: 0.0010
# Epoch 21/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8992 - auc: 0.9685 - loss: 0.4372 - precision: 0.2453 - recall: 0.9081
# Epoch 21: val_auc did not improve from 0.95275
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8992 - auc: 0.9685 - loss: 0.4372 - precision: 0.2453 - recall: 0.9081 - val_accuracy: 0.9262 - val_auc: 0.9517 - val_loss: 0.1706 - val_precision: 0.2996 - val_recall: 0.8289 - learning_rate: 0.0010
# Epoch 22/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8992 - auc: 0.9701 - loss: 0.4257 - precision: 0.2455 - recall: 0.9112
# Epoch 22: val_auc improved from 0.95275 to 0.95435, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8991 - auc: 0.9701 - loss: 0.4257 - precision: 0.2455 - recall: 0.9112 - val_accuracy: 0.9340 - val_auc: 0.9543 - val_loss: 0.1658 - val_precision: 0.3243 - val_recall: 0.8176 - learning_rate: 0.0010
# Epoch 23/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9041 - auc: 0.9704 - loss: 0.4233 - precision: 0.2545 - recall: 0.9069
# Epoch 23: val_auc did not improve from 0.95435
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9041 - auc: 0.9704 - loss: 0.4233 - precision: 0.2545 - recall: 0.9069 - val_accuracy: 0.9424 - val_auc: 0.9507 - val_loss: 0.1468 - val_precision: 0.3549 - val_recall: 0.7895 - learning_rate: 0.0010
# Epoch 24/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9054 - auc: 0.9705 - loss: 0.4218 - precision: 0.2573 - recall: 0.9062
# Epoch 24: val_auc did not improve from 0.95435
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9054 - auc: 0.9705 - loss: 0.4217 - precision: 0.2573 - recall: 0.9062 - val_accuracy: 0.9448 - val_auc: 0.9529 - val_loss: 0.1427 - val_precision: 0.3667 - val_recall: 0.7931 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9046 - auc: 0.9718 - loss: 0.4137 - precision: 0.2565 - recall: 0.9134
# Epoch 25: val_auc did not improve from 0.95435
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9046 - auc: 0.9718 - loss: 0.4137 - precision: 0.2565 - recall: 0.9134 - val_accuracy: 0.9403 - val_auc: 0.9532 - val_loss: 0.1461 - val_precision: 0.3481 - val_recall: 0.8076 - learning_rate: 0.0010
# Epoch 26/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9057 - auc: 0.9725 - loss: 0.4077 - precision: 0.2583 - recall: 0.9103
# Epoch 26: val_auc improved from 0.95435 to 0.95455, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9057 - auc: 0.9725 - loss: 0.4077 - precision: 0.2583 - recall: 0.9103 - val_accuracy: 0.9460 - val_auc: 0.9546 - val_loss: 0.1455 - val_precision: 0.3731 - val_recall: 0.7997 - learning_rate: 0.0010
# Epoch 27/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9115 - auc: 0.9739 - loss: 0.3974 - precision: 0.2716 - recall: 0.9139
# Epoch 27: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9114 - auc: 0.9739 - loss: 0.3975 - precision: 0.2715 - recall: 0.9139 - val_accuracy: 0.9436 - val_auc: 0.9523 - val_loss: 0.1475 - val_precision: 0.3611 - val_recall: 0.7958 - learning_rate: 0.0010
# Epoch 28/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9086 - auc: 0.9734 - loss: 0.4007 - precision: 0.2656 - recall: 0.9166
# Epoch 28: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9086 - auc: 0.9734 - loss: 0.4007 - precision: 0.2655 - recall: 0.9166 - val_accuracy: 0.9381 - val_auc: 0.9521 - val_loss: 0.1466 - val_precision: 0.3390 - val_recall: 0.8091 - learning_rate: 0.0010
# Epoch 29/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9062 - auc: 0.9743 - loss: 0.3936 - precision: 0.2605 - recall: 0.9188
# Epoch 29: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9062 - auc: 0.9743 - loss: 0.3936 - precision: 0.2605 - recall: 0.9188 - val_accuracy: 0.9411 - val_auc: 0.9520 - val_loss: 0.1391 - val_precision: 0.3504 - val_recall: 0.7985 - learning_rate: 0.0010
# Epoch 30/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9084 - auc: 0.9745 - loss: 0.3930 - precision: 0.2657 - recall: 0.9215
# Epoch 30: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9084 - auc: 0.9745 - loss: 0.3930 - precision: 0.2656 - recall: 0.9215 - val_accuracy: 0.9426 - val_auc: 0.9508 - val_loss: 0.1386 - val_precision: 0.3560 - val_recall: 0.7926 - learning_rate: 0.0010
# Epoch 31/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9086 - auc: 0.9754 - loss: 0.3853 - precision: 0.2667 - recall: 0.9251
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 31: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9086 - auc: 0.9754 - loss: 0.3853 - precision: 0.2667 - recall: 0.9251 - val_accuracy: 0.9425 - val_auc: 0.9529 - val_loss: 0.1411 - val_precision: 0.3561 - val_recall: 0.7946 - learning_rate: 0.0010
# Epoch 32/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9094 - auc: 0.9765 - loss: 0.3762 - precision: 0.2682 - recall: 0.9245
# Epoch 32: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9094 - auc: 0.9765 - loss: 0.3761 - precision: 0.2683 - recall: 0.9245 - val_accuracy: 0.9458 - val_auc: 0.9520 - val_loss: 0.1256 - val_precision: 0.3723 - val_recall: 0.7980 - learning_rate: 5.0000e-04
# Epoch 33/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9126 - auc: 0.9791 - loss: 0.3528 - precision: 0.2769 - recall: 0.9340
# Epoch 33: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9126 - auc: 0.9791 - loss: 0.3528 - precision: 0.2769 - recall: 0.9340 - val_accuracy: 0.9464 - val_auc: 0.9523 - val_loss: 0.1266 - val_precision: 0.3743 - val_recall: 0.7934 - learning_rate: 5.0000e-04
# Epoch 34/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9153 - auc: 0.9790 - loss: 0.3543 - precision: 0.2834 - recall: 0.9333
# Epoch 34: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9153 - auc: 0.9790 - loss: 0.3543 - precision: 0.2834 - recall: 0.9333 - val_accuracy: 0.9493 - val_auc: 0.9524 - val_loss: 0.1215 - val_precision: 0.3893 - val_recall: 0.7914 - learning_rate: 5.0000e-04
# Epoch 35/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9173 - auc: 0.9801 - loss: 0.3441 - precision: 0.2888 - recall: 0.9364
# Epoch 35: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9173 - auc: 0.9801 - loss: 0.3440 - precision: 0.2888 - recall: 0.9364 - val_accuracy: 0.9479 - val_auc: 0.9533 - val_loss: 0.1227 - val_precision: 0.3820 - val_recall: 0.7897 - learning_rate: 5.0000e-04
# Epoch 36/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9150 - auc: 0.9805 - loss: 0.3412 - precision: 0.2831 - recall: 0.9357
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 36: val_auc did not improve from 0.95455
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9150 - auc: 0.9805 - loss: 0.3412 - precision: 0.2831 - recall: 0.9358 - val_accuracy: 0.9529 - val_auc: 0.9511 - val_loss: 0.1166 - val_precision: 0.4091 - val_recall: 0.7786 - learning_rate: 5.0000e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Final model training complete!
# ✅ Final model saved: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/final_model.h5
