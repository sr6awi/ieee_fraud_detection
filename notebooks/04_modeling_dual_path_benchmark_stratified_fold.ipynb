# %% [markdown]
# <a href="https://colab.research.google.com/github/sr6awi/ieee_fraud_detection/blob/main/notebooks/04_modeling_dual_path_benchmark_stratified_fold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

print("=" * 70)
print("🚀 DUAL-PATH FRAUD DETECTION - COMPLETE TRAINING PIPELINE")
print("Node Classification with Full Dataset Support")
print("=" * 70)

# GPU Configuration
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU: {len(gpus)} device(s) available")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No GPU - using CPU (slower)")

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
# Out:
# ======================================================================
# 🚀 DUAL-PATH FRAUD DETECTION - COMPLETE TRAINING PIPELINE
# Node Classification with Full Dataset Support
# ======================================================================
# ✅ GPU: 1 device(s) available

# %%
BASE_DIR = Path("/content/drive/MyDrive/ML_Projects/ieee-fraud-detection")
PROCESSED_DIR = BASE_DIR / "processed"
MODEL_DIR = BASE_DIR / "models"
RESULTS_DIR = BASE_DIR / "results"

MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Training configuration
CONFIG = {
    'batch_size': 1024,
    'epochs': 50,
    'learning_rate': 0.001,
    'patience': 10,
    'n_folds': 5,
    'use_class_weights': True,
    'save_best_only': True
}

print(f"\n📁 Directories:")
print(f"   Data: {PROCESSED_DIR}")
print(f"   Models: {MODEL_DIR}")
print(f"   Results: {RESULTS_DIR}")
# Out:
# 📁 Directories:
#    Data: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/processed
#    Models: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models
#    Results: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/results

# %%
print("\n" + "="*70)
print("📥 LOADING FEATURE-ENGINEERED DATA")
print("="*70)

print("\nLoading training data...")
train = pd.read_csv(PROCESSED_DIR / "train_feature_engineered.csv")
print(f"✅ Train loaded: {train.shape}")

print("Loading test data...")
test = pd.read_csv(PROCESSED_DIR / "test_feature_engineered.csv")
print(f"✅ Test loaded: {test.shape}")

# Check for target
if 'isFraud' not in train.columns:
    raise ValueError("Target 'isFraud' not found in training data!")

print(f"\n📊 Data Statistics:")
print(f"   Training samples: {len(train):,}")
print(f"   Test samples: {len(test):,}")
print(f"   Features: {train.shape[1] - 2}")  # Exclude isFraud and TransactionID
print(f"   Fraud rate: {train['isFraud'].mean()*100:.2f}%")
print(f"   Class imbalance: {(1-train['isFraud'].mean())/train['isFraud'].mean():.1f}:1")
# Out:
# ======================================================================
# 📥 LOADING FEATURE-ENGINEERED DATA
# ======================================================================
#
# Loading training data...
# ✅ Train loaded: (590540, 262)
# Loading test data...
# ✅ Test loaded: (506691, 261)
#
# 📊 Data Statistics:
#    Training samples: 590,540
#    Test samples: 506,691
#    Features: 260
#    Fraud rate: 3.50%
#    Class imbalance: 27.6:1

# %%
print("\n" + "="*70)
print("🎯 PREPARING FEATURES FOR DUAL PATHS")
print("="*70)

# Smart features for GNN (features that benefit from graph structure)
GNN_FEATURES = [
    'TransactionAmt', 'TransactionDT',
    'card1', 'card2', 'card1_count',
    'card1_fraud_rate', 'card2_fraud_rate',
    'P_emaildomain_fraud_rate', 'R_emaildomain_fraud_rate',
    'addr1', 'dist1', 'ProductCD', 'ProductCD_fraud_rate',
    'transaction_hour', 'is_weekend', 'is_night',
    'TransactionAmt_log', 'email_domains_match', 'addr_match'
]

# Filter available GNN features
GNN_FEATURES = [f for f in GNN_FEATURES if f in train.columns]

print(f"✅ GNN Path: {len(GNN_FEATURES)} smart features selected")
print(f"   Focus: Graph-beneficial features")

# All features for TabNet (exclude ID and target)
exclude_cols = ['isFraud', 'TransactionID']
TABNET_FEATURES = [c for c in train.columns if c not in exclude_cols]

print(f"✅ TabNet Path: {len(TABNET_FEATURES)} features (all available)")
print(f"   Focus: Rich feature learning")
# Out:
# ======================================================================
# 🎯 PREPARING FEATURES FOR DUAL PATHS
# ======================================================================
# ✅ GNN Path: 19 smart features selected
#    Focus: Graph-beneficial features
# ✅ TabNet Path: 260 features (all available)
#    Focus: Rich feature learning

# %%
print("\n" + "="*70)
print("📊 PREPARING TRAINING DATA (SIMPLIFIED FOR MEMORY)")
print("="*70)

"""
SIMPLIFIED APPROACH:
- Skip graph construction for now (memory intensive)
- Use GNN features as regular neural network
- Focus on TabNet path primarily
- Treat as multi-modal learning (two feature sets)
"""

# Prepare features
X_gnn = train[GNN_FEATURES].fillna(0).values
X_tabnet = train[TABNET_FEATURES].fillna(0).values
y = train['isFraud'].values

X_gnn_test = test[GNN_FEATURES].fillna(0).values
X_tabnet_test = test[TABNET_FEATURES].fillna(0).values

print(f"✅ Training data prepared:")
print(f"   GNN input shape: {X_gnn.shape}")
print(f"   TabNet input shape: {X_tabnet.shape}")
print(f"   Labels shape: {y.shape}")

# Normalize features
print("\n📏 Normalizing features...")
scaler_gnn = StandardScaler()
scaler_tabnet = StandardScaler()

X_gnn_scaled = scaler_gnn.fit_transform(X_gnn)
X_tabnet_scaled = scaler_tabnet.fit_transform(X_tabnet)

X_gnn_test_scaled = scaler_gnn.transform(X_gnn_test)
X_tabnet_test_scaled = scaler_tabnet.transform(X_tabnet_test)

# Save scalers
import joblib
joblib.dump(scaler_gnn, MODEL_DIR / 'scaler_gnn.pkl')
joblib.dump(scaler_tabnet, MODEL_DIR / 'scaler_tabnet.pkl')

print("✅ Features normalized and scalers saved!")
# Out:
# ======================================================================
# 📊 PREPARING TRAINING DATA (SIMPLIFIED FOR MEMORY)
# ======================================================================
# ✅ Training data prepared:
#    GNN input shape: (590540, 19)
#    TabNet input shape: (590540, 260)
#    Labels shape: (590540,)
#
# 📏 Normalizing features...
# ✅ Features normalized and scalers saved!

# %%
print("\n" + "="*70)
print("🏗️ BUILDING SIMPLIFIED DUAL-PATH MODEL")
print("="*70)

def build_dual_path_model(gnn_features, tabnet_features):
    """
    Simplified dual-path architecture for production training.
    Treats GNN features as a separate neural network path.
    """

    # INPUT LAYERS
    input_gnn = layers.Input(shape=(gnn_features,), name='gnn_input')
    input_tabnet = layers.Input(shape=(tabnet_features,), name='tabnet_input')

    # PATH 1: GNN-style Network (processes graph-beneficial features)
    x1 = layers.Dense(128, activation='relu', name='gnn_dense1')(input_gnn)
    x1 = layers.BatchNormalization(name='gnn_bn1')(x1)
    x1 = layers.Dropout(0.3, name='gnn_dropout1')(x1)

    x1 = layers.Dense(64, activation='relu', name='gnn_dense2')(x1)
    x1 = layers.BatchNormalization(name='gnn_bn2')(x1)
    x1 = layers.Dropout(0.2, name='gnn_dropout2')(x1)

    gnn_output = layers.Dense(32, activation='relu', name='gnn_output')(x1)

    # PATH 2: TabNet-style Network (attention-based feature selection)
    # Step 1
    x2 = layers.Dense(256, activation='gelu', name='tabnet_step1')(input_tabnet)
    x2 = layers.BatchNormalization(name='tabnet_bn1')(x2)
    x2 = layers.Dropout(0.3, name='tabnet_dropout1')(x2)

    # Step 2
    x2 = layers.Dense(128, activation='gelu', name='tabnet_step2')(x2)
    x2 = layers.BatchNormalization(name='tabnet_bn2')(x2)
    x2 = layers.Dropout(0.2, name='tabnet_dropout2')(x2)

    # Step 3
    tabnet_output = layers.Dense(32, activation='relu', name='tabnet_output')(x2)

    # FUSION: Concatenate both paths
    merged = layers.Concatenate(name='fusion_concat')([gnn_output, tabnet_output])

    # Attention-based fusion
    attention_weights = layers.Dense(64, activation='softmax', name='attention_weights')(merged)
    attended = layers.Multiply(name='attended_features')([merged, attention_weights])

    # Final classification layers
    x = layers.Dense(64, activation='relu', name='classifier_dense1')(attended)
    x = layers.BatchNormalization(name='classifier_bn')(x)
    x = layers.Dropout(0.2, name='classifier_dropout')(x)

    x = layers.Dense(32, activation='relu', name='classifier_dense2')(x)

    # Output
    output = layers.Dense(1, activation='sigmoid', name='output')(x)

    # Create model
    model = keras.Model(
        inputs=[input_gnn, input_tabnet],
        outputs=output,
        name='DualPathFraudDetector'
    )

    return model

# Build model
model = build_dual_path_model(len(GNN_FEATURES), len(TABNET_FEATURES))

print("✅ Model architecture built!")
print(f"\n📋 Model Summary:")
model.summary()
# Out:
# ======================================================================
# 🏗️ BUILDING SIMPLIFIED DUAL-PATH MODEL
# ======================================================================
# ✅ Model architecture built!
#
# 📋 Model Summary:
# Model: "DualPathFraudDetector"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ gnn_input           │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_input        │ (None, 260)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dense1 (Dense)  │ (None, 128)       │      2,560 │ gnn_input[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_step1        │ (None, 256)       │     66,816 │ tabnet_input[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_bn1             │ (None, 128)       │        512 │ gnn_dense1[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_bn1          │ (None, 256)       │      1,024 │ tabnet_step1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dropout1        │ (None, 128)       │          0 │ gnn_bn1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_dropout1     │ (None, 256)       │          0 │ tabnet_bn1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dense2 (Dense)  │ (None, 64)        │      8,256 │ gnn_dropout1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_step2        │ (None, 128)       │     32,896 │ tabnet_dropout1[… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_bn2             │ (None, 64)        │        256 │ gnn_dense2[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_bn2          │ (None, 128)       │        512 │ tabnet_step2[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_dropout2        │ (None, 64)        │          0 │ gnn_bn2[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_dropout2     │ (None, 128)       │          0 │ tabnet_bn2[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gnn_output (Dense)  │ (None, 32)        │      2,080 │ gnn_dropout2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabnet_output       │ (None, 32)        │      4,128 │ tabnet_dropout2[… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion_concat       │ (None, 64)        │          0 │ gnn_output[0][0], │
# │ (Concatenate)       │                   │            │ tabnet_output[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_weights   │ (None, 64)        │      4,160 │ fusion_concat[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attended_features   │ (None, 64)        │          0 │ fusion_concat[0]… │
# │ (Multiply)          │                   │            │ attention_weight… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense1   │ (None, 64)        │      4,160 │ attended_feature… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_bn       │ (None, 64)        │        256 │ classifier_dense… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dropout  │ (None, 64)        │          0 │ classifier_bn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense2   │ (None, 32)        │      2,080 │ classifier_dropo… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │         33 │ classifier_dense… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 129,729 (506.75 KB)
#  Trainable params: 128,449 (501.75 KB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
print("\n" + "="*70)
print("⚙️ COMPILING MODEL")
print("="*70)

# Calculate class weights for imbalanced data
fraud_rate = y.mean()
class_weight = {
    0: 1.0,
    1: (1 - fraud_rate) / fraud_rate
}

print(f"📊 Class weights (for imbalance):")
print(f"   Class 0 (Legit): {class_weight[0]:.2f}")
print(f"   Class 1 (Fraud): {class_weight[1]:.2f}")

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=CONFIG['learning_rate']),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        keras.metrics.AUC(name='auc'),
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall')
    ]
)

print("\n✅ Model compiled successfully!")
# Out:
# ======================================================================
# ⚙️ COMPILING MODEL
# ======================================================================
# 📊 Class weights (for imbalance):
#    Class 0 (Legit): 1.00
#    Class 1 (Fraud): 27.58
#
# ✅ Model compiled successfully!

# %%
# !pip install keras-tqdm
# Out:
# Requirement already satisfied: keras-tqdm in /usr/local/lib/python3.12/dist-packages (2.0.1)
# Requirement already satisfied: Keras in /usr/local/lib/python3.12/dist-packages (from keras-tqdm) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from keras-tqdm) (4.67.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from Keras->keras-tqdm) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->Keras->keras-tqdm) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras->keras-tqdm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->Keras->keras-tqdm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->Keras->keras-tqdm) (0.1.2)

# %%
print("\n" + "="*70)
print("🎓 TRAINING WITH STRATIFIED K-FOLD CROSS-VALIDATION")
print("="*70)

from tensorflow.keras.callbacks import LambdaCallback

# Base callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_auc',
        patience=CONFIG['patience'],
        restore_best_weights=True,
        mode='max',
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_auc',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
]

# Stratified K-Fold setup
skf = StratifiedKFold(n_splits=CONFIG['n_folds'], shuffle=True, random_state=SEED)

cv_scores = []
fold_histories = []

print(f"\n🔄 Starting {CONFIG['n_folds']}-Fold Cross-Validation...")
print("="*70)

for fold, (train_idx, val_idx) in enumerate(skf.split(X_gnn_scaled, y), 1):
    print(f"\n{'='*70}")
    print(f"📊 FOLD {fold}/{CONFIG['n_folds']}")
    print(f"{'='*70}")

    # Split data
    X_gnn_train, X_gnn_val = X_gnn_scaled[train_idx], X_gnn_scaled[val_idx]
    X_tabnet_train, X_tabnet_val = X_tabnet_scaled[train_idx], X_tabnet_scaled[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    print(f"   Train: {len(y_train):,} samples ({y_train.mean()*100:.2f}% fraud)")
    print(f"   Val:   {len(y_val):,} samples ({y_val.mean()*100:.2f}% fraud)")

    # Rebuild model (fresh weights for each fold)
    model = build_dual_path_model(len(GNN_FEATURES), len(TABNET_FEATURES))
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=CONFIG['learning_rate']),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            keras.metrics.AUC(name='auc'),
            keras.metrics.Precision(name='precision'),
            keras.metrics.Recall(name='recall')
        ]
    )

    # Custom epoch logger for short summaries
    epoch_logger = LambdaCallback(
        on_epoch_end=lambda e, logs:
            print(f"Epoch {e+1:02d} | "
                  f"loss={logs['loss']:.4f} | val_loss={logs['val_loss']:.4f} | "
                  f"auc={logs['auc']:.4f} | val_auc={logs['val_auc']:.4f}")
    )

    # Create callbacks for this fold (unique checkpoint path)
    fold_callbacks = callbacks.copy() + [
        keras.callbacks.ModelCheckpoint(
            filepath=str(MODEL_DIR / f'best_model_fold_{fold}.keras'),
            monitor='val_auc',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        epoch_logger
    ]

    # Train
    print(f"\n   🚀 Training...")
    history = model.fit(
        [X_gnn_train, X_tabnet_train],
        y_train,
        validation_data=([X_gnn_val, X_tabnet_val], y_val),
        epochs=CONFIG['epochs'],
        batch_size=CONFIG['batch_size'],
        class_weight=class_weight if CONFIG['use_class_weights'] else None,
        callbacks=fold_callbacks,
        verbose=1      # ✅ live progress bar
    )

    # Evaluate
    val_preds = model.predict([X_gnn_val, X_tabnet_val], verbose=0)
    val_auc = roc_auc_score(y_val, val_preds)
    cv_scores.append(val_auc)
    fold_histories.append(history.history)

    print(f"\n   ✅ Fold {fold} Complete!")
    print(f"   Val AUC: {val_auc:.6f}")
    print(f"   Best epoch: {np.argmax(history.history['val_auc']) + 1}")

# ============================================================================
# RESULTS SUMMARY
# ============================================================================

print("\n" + "="*70)
print("📊 CROSS-VALIDATION RESULTS")
print("="*70)

print(f"\nFold AUC Scores:")
for i, score in enumerate(cv_scores, 1):
    print(f"   Fold {i}: {score:.6f}")

print(f"\n🏆 Summary:")
print(f"   Mean AUC: {np.mean(cv_scores):.6f}")
print(f"   Std AUC:  {np.std(cv_scores):.6f}")
print(f"   Min AUC:  {np.min(cv_scores):.6f}")
print(f"   Max AUC:  {np.max(cv_scores):.6f}")

# Save cross-validation results
cv_results = {
    'fold_scores': cv_scores,
    'mean_auc': float(np.mean(cv_scores)),
    'std_auc': float(np.std(cv_scores)),
    'config': CONFIG
}

with open(RESULTS_DIR / 'cv_results.json', 'w') as f:
    json.dump(cv_results, f, indent=2)

print(f"\n✅ CV results saved to: {RESULTS_DIR / 'cv_results.json'}")
# Out:
# ======================================================================
# 🎓 TRAINING WITH STRATIFIED K-FOLD CROSS-VALIDATION
# ======================================================================
#
# 🔄 Starting 5-Fold Cross-Validation...
# ======================================================================
#
# ======================================================================
# 📊 FOLD 1/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6845 - auc: 0.8222 - loss: 0.9941 - precision: 0.0934 - recall: 0.7882
# Epoch 1: val_auc improved from -inf to 0.91795, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 01 | loss=0.8427 | val_loss=0.2499 | auc=0.8777 | val_auc=0.9180
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.6848 - auc: 0.8223 - loss: 0.9938 - precision: 0.0935 - recall: 0.7883 - val_accuracy: 0.9209 - val_auc: 0.9180 - val_loss: 0.2499 - val_precision: 0.2670 - val_recall: 0.7227 - learning_rate: 0.0010
# Epoch 2/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8446 - auc: 0.9132 - loss: 0.7215 - precision: 0.1626 - recall: 0.8147
# Epoch 2: val_auc improved from 0.91795 to 0.92926, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 02 | loss=0.6919 | val_loss=0.2704 | auc=0.9193 | val_auc=0.9293
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.8447 - auc: 0.9133 - loss: 0.7211 - precision: 0.1627 - recall: 0.8147 - val_accuracy: 0.8834 - val_auc: 0.9293 - val_loss: 0.2704 - val_precision: 0.2038 - val_recall: 0.8025 - learning_rate: 0.0010
# Epoch 3/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8575 - auc: 0.9259 - loss: 0.6672 - precision: 0.1770 - recall: 0.8279
# Epoch 3: val_auc improved from 0.92926 to 0.93380, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 03 | loss=0.6498 | val_loss=0.2586 | auc=0.9292 | val_auc=0.9338
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8575 - auc: 0.9260 - loss: 0.6671 - precision: 0.1771 - recall: 0.8279 - val_accuracy: 0.8861 - val_auc: 0.9338 - val_loss: 0.2586 - val_precision: 0.2092 - val_recall: 0.8115 - learning_rate: 0.0010
# Epoch 4/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8637 - auc: 0.9317 - loss: 0.6432 - precision: 0.1857 - recall: 0.8399
# Epoch 4: val_auc improved from 0.93380 to 0.93651, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 04 | loss=0.6237 | val_loss=0.2688 | auc=0.9350 | val_auc=0.9365
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8638 - auc: 0.9317 - loss: 0.6430 - precision: 0.1857 - recall: 0.8399 - val_accuracy: 0.8838 - val_auc: 0.9365 - val_loss: 0.2688 - val_precision: 0.2075 - val_recall: 0.8238 - learning_rate: 0.0010
# Epoch 5/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8664 - auc: 0.9375 - loss: 0.6159 - precision: 0.1902 - recall: 0.8497
# Epoch 5: val_auc improved from 0.93651 to 0.94079, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 05 | loss=0.6026 | val_loss=0.2418 | auc=0.9394 | val_auc=0.9408
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8664 - auc: 0.9375 - loss: 0.6158 - precision: 0.1902 - recall: 0.8497 - val_accuracy: 0.8998 - val_auc: 0.9408 - val_loss: 0.2418 - val_precision: 0.2329 - val_recall: 0.8134 - learning_rate: 0.0010
# Epoch 6/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8708 - auc: 0.9410 - loss: 0.5995 - precision: 0.1965 - recall: 0.8563
# Epoch 6: val_auc improved from 0.94079 to 0.94172, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 06 | loss=0.5850 | val_loss=0.2433 | auc=0.9432 | val_auc=0.9417
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8709 - auc: 0.9411 - loss: 0.5993 - precision: 0.1966 - recall: 0.8563 - val_accuracy: 0.8949 - val_auc: 0.9417 - val_loss: 0.2433 - val_precision: 0.2261 - val_recall: 0.8270 - learning_rate: 0.0010
# Epoch 7/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8722 - auc: 0.9448 - loss: 0.5799 - precision: 0.1991 - recall: 0.8621
# Epoch 7: val_auc improved from 0.94172 to 0.94418, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 07 | loss=0.5674 | val_loss=0.2387 | auc=0.9465 | val_auc=0.9442
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8722 - auc: 0.9448 - loss: 0.5799 - precision: 0.1992 - recall: 0.8621 - val_accuracy: 0.9031 - val_auc: 0.9442 - val_loss: 0.2387 - val_precision: 0.2407 - val_recall: 0.8214 - learning_rate: 0.0010
# Epoch 8/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8804 - auc: 0.9474 - loss: 0.5666 - precision: 0.2110 - recall: 0.8662
# Epoch 8: val_auc improved from 0.94418 to 0.94496, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 08 | loss=0.5539 | val_loss=0.2348 | auc=0.9491 | val_auc=0.9450
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8804 - auc: 0.9474 - loss: 0.5664 - precision: 0.2110 - recall: 0.8662 - val_accuracy: 0.9090 - val_auc: 0.9450 - val_loss: 0.2348 - val_precision: 0.2532 - val_recall: 0.8214 - learning_rate: 0.0010
# Epoch 9/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8794 - auc: 0.9501 - loss: 0.5521 - precision: 0.2097 - recall: 0.8665
# Epoch 9: val_auc improved from 0.94496 to 0.94694, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 09 | loss=0.5393 | val_loss=0.2063 | auc=0.9519 | val_auc=0.9469
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8795 - auc: 0.9501 - loss: 0.5520 - precision: 0.2097 - recall: 0.8666 - val_accuracy: 0.9193 - val_auc: 0.9469 - val_loss: 0.2063 - val_precision: 0.2763 - val_recall: 0.8076 - learning_rate: 0.0010
# Epoch 10/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8851 - auc: 0.9526 - loss: 0.5396 - precision: 0.2187 - recall: 0.8714
# Epoch 10: val_auc improved from 0.94694 to 0.94881, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 10 | loss=0.5274 | val_loss=0.2099 | auc=0.9541 | val_auc=0.9488
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8851 - auc: 0.9526 - loss: 0.5396 - precision: 0.2187 - recall: 0.8714 - val_accuracy: 0.9137 - val_auc: 0.9488 - val_loss: 0.2099 - val_precision: 0.2647 - val_recall: 0.8245 - learning_rate: 0.0010
# Epoch 11/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8825 - auc: 0.9546 - loss: 0.5272 - precision: 0.2158 - recall: 0.8787
# Epoch 11: val_auc did not improve from 0.94881
# Epoch 11 | loss=0.5163 | val_loss=0.2153 | auc=0.9560 | val_auc=0.9474
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8825 - auc: 0.9546 - loss: 0.5271 - precision: 0.2158 - recall: 0.8787 - val_accuracy: 0.9121 - val_auc: 0.9474 - val_loss: 0.2153 - val_precision: 0.2604 - val_recall: 0.8226 - learning_rate: 0.0010
# Epoch 12/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8877 - auc: 0.9562 - loss: 0.5190 - precision: 0.2238 - recall: 0.8783
# Epoch 12: val_auc improved from 0.94881 to 0.95015, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 12 | loss=0.5091 | val_loss=0.1997 | auc=0.9572 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8878 - auc: 0.9562 - loss: 0.5188 - precision: 0.2238 - recall: 0.8783 - val_accuracy: 0.9207 - val_auc: 0.9502 - val_loss: 0.1997 - val_precision: 0.2816 - val_recall: 0.8166 - learning_rate: 0.0010
# Epoch 13/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8865 - auc: 0.9588 - loss: 0.5019 - precision: 0.2229 - recall: 0.8857
# Epoch 13: val_auc improved from 0.95015 to 0.95080, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 13 | loss=0.4956 | val_loss=0.2126 | auc=0.9595 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8865 - auc: 0.9588 - loss: 0.5019 - precision: 0.2229 - recall: 0.8857 - val_accuracy: 0.9125 - val_auc: 0.9508 - val_loss: 0.2126 - val_precision: 0.2636 - val_recall: 0.8374 - learning_rate: 0.0010
# Epoch 14/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8839 - auc: 0.9599 - loss: 0.4951 - precision: 0.2193 - recall: 0.8875
# Epoch 14: val_auc improved from 0.95080 to 0.95104, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 14 | loss=0.4869 | val_loss=0.1930 | auc=0.9609 | val_auc=0.9510
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8840 - auc: 0.9599 - loss: 0.4950 - precision: 0.2194 - recall: 0.8876 - val_accuracy: 0.9279 - val_auc: 0.9510 - val_loss: 0.1930 - val_precision: 0.3030 - val_recall: 0.8153 - learning_rate: 0.0010
# Epoch 15/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8915 - auc: 0.9607 - loss: 0.4906 - precision: 0.2311 - recall: 0.8862
# Epoch 15: val_auc improved from 0.95104 to 0.95247, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 15 | loss=0.4824 | val_loss=0.1940 | auc=0.9616 | val_auc=0.9525
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8915 - auc: 0.9607 - loss: 0.4906 - precision: 0.2311 - recall: 0.8862 - val_accuracy: 0.9251 - val_auc: 0.9525 - val_loss: 0.1940 - val_precision: 0.2958 - val_recall: 0.8260 - learning_rate: 0.0010
# Epoch 16/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8932 - auc: 0.9617 - loss: 0.4856 - precision: 0.2345 - recall: 0.8894
# Epoch 16: val_auc did not improve from 0.95247
# Epoch 16 | loss=0.4756 | val_loss=0.2028 | auc=0.9628 | val_auc=0.9524
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8932 - auc: 0.9617 - loss: 0.4855 - precision: 0.2345 - recall: 0.8894 - val_accuracy: 0.9120 - val_auc: 0.9524 - val_loss: 0.2028 - val_precision: 0.2625 - val_recall: 0.8383 - learning_rate: 0.0010
# Epoch 17/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8893 - auc: 0.9633 - loss: 0.4756 - precision: 0.2295 - recall: 0.8999
# Epoch 17: val_auc improved from 0.95247 to 0.95279, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 17 | loss=0.4654 | val_loss=0.2010 | auc=0.9644 | val_auc=0.9528
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8894 - auc: 0.9633 - loss: 0.4755 - precision: 0.2296 - recall: 0.8999 - val_accuracy: 0.9196 - val_auc: 0.9528 - val_loss: 0.2010 - val_precision: 0.2813 - val_recall: 0.8347 - learning_rate: 0.0010
# Epoch 18/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8952 - auc: 0.9653 - loss: 0.4621 - precision: 0.2398 - recall: 0.9019
# Epoch 18: val_auc did not improve from 0.95279
# Epoch 18 | loss=0.4584 | val_loss=0.1756 | auc=0.9655 | val_auc=0.9527
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8952 - auc: 0.9653 - loss: 0.4621 - precision: 0.2398 - recall: 0.9019 - val_accuracy: 0.9278 - val_auc: 0.9527 - val_loss: 0.1756 - val_precision: 0.3041 - val_recall: 0.8250 - learning_rate: 0.0010
# Epoch 19/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8951 - auc: 0.9659 - loss: 0.4583 - precision: 0.2396 - recall: 0.9010
# Epoch 19: val_auc improved from 0.95279 to 0.95346, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 19 | loss=0.4526 | val_loss=0.1913 | auc=0.9663 | val_auc=0.9535
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8951 - auc: 0.9659 - loss: 0.4582 - precision: 0.2396 - recall: 0.9010 - val_accuracy: 0.9206 - val_auc: 0.9535 - val_loss: 0.1913 - val_precision: 0.2840 - val_recall: 0.8354 - learning_rate: 0.0010
# Epoch 20/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8952 - auc: 0.9665 - loss: 0.4531 - precision: 0.2402 - recall: 0.9038
# Epoch 20: val_auc did not improve from 0.95346
# Epoch 20 | loss=0.4450 | val_loss=0.1843 | auc=0.9674 | val_auc=0.9529
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8952 - auc: 0.9665 - loss: 0.4531 - precision: 0.2402 - recall: 0.9038 - val_accuracy: 0.9305 - val_auc: 0.9529 - val_loss: 0.1843 - val_precision: 0.3123 - val_recall: 0.8199 - learning_rate: 0.0010
# Epoch 21/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8937 - auc: 0.9670 - loss: 0.4494 - precision: 0.2374 - recall: 0.9036
# Epoch 21: val_auc improved from 0.95346 to 0.95363, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 21 | loss=0.4411 | val_loss=0.1858 | auc=0.9679 | val_auc=0.9536
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8937 - auc: 0.9670 - loss: 0.4494 - precision: 0.2374 - recall: 0.9036 - val_accuracy: 0.9217 - val_auc: 0.9536 - val_loss: 0.1858 - val_precision: 0.2872 - val_recall: 0.8357 - learning_rate: 0.0010
# Epoch 22/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8970 - auc: 0.9683 - loss: 0.4415 - precision: 0.2440 - recall: 0.9082
# Epoch 22: val_auc improved from 0.95363 to 0.95470, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 22 | loss=0.4318 | val_loss=0.1835 | auc=0.9693 | val_auc=0.9547
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8970 - auc: 0.9683 - loss: 0.4413 - precision: 0.2440 - recall: 0.9083 - val_accuracy: 0.9216 - val_auc: 0.9547 - val_loss: 0.1835 - val_precision: 0.2873 - val_recall: 0.8374 - learning_rate: 0.0010
# Epoch 23/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8966 - auc: 0.9691 - loss: 0.4358 - precision: 0.2435 - recall: 0.9103
# Epoch 23: val_auc did not improve from 0.95470
# Epoch 23 | loss=0.4276 | val_loss=0.1789 | auc=0.9699 | val_auc=0.9537
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8966 - auc: 0.9691 - loss: 0.4357 - precision: 0.2435 - recall: 0.9103 - val_accuracy: 0.9208 - val_auc: 0.9537 - val_loss: 0.1789 - val_precision: 0.2851 - val_recall: 0.8388 - learning_rate: 0.0010
# Epoch 24/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8968 - auc: 0.9695 - loss: 0.4341 - precision: 0.2439 - recall: 0.9101
# Epoch 24: val_auc did not improve from 0.95470
# Epoch 24 | loss=0.4246 | val_loss=0.1721 | auc=0.9703 | val_auc=0.9541
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8968 - auc: 0.9695 - loss: 0.4340 - precision: 0.2439 - recall: 0.9101 - val_accuracy: 0.9279 - val_auc: 0.9541 - val_loss: 0.1721 - val_precision: 0.3051 - val_recall: 0.8303 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9001 - auc: 0.9705 - loss: 0.4255 - precision: 0.2503 - recall: 0.9114
# Epoch 25: val_auc did not improve from 0.95470
# Epoch 25 | loss=0.4205 | val_loss=0.1720 | auc=0.9708 | val_auc=0.9533
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9001 - auc: 0.9705 - loss: 0.4255 - precision: 0.2503 - recall: 0.9114 - val_accuracy: 0.9320 - val_auc: 0.9533 - val_loss: 0.1720 - val_precision: 0.3171 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 26/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9030 - auc: 0.9716 - loss: 0.4162 - precision: 0.2563 - recall: 0.9130
# Epoch 26: val_auc did not improve from 0.95470
# Epoch 26 | loss=0.4108 | val_loss=0.1661 | auc=0.9721 | val_auc=0.9532
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9030 - auc: 0.9716 - loss: 0.4162 - precision: 0.2563 - recall: 0.9130 - val_accuracy: 0.9352 - val_auc: 0.9532 - val_loss: 0.1661 - val_precision: 0.3285 - val_recall: 0.8146 - learning_rate: 0.0010
# Epoch 27/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9047 - auc: 0.9719 - loss: 0.4150 - precision: 0.2599 - recall: 0.9135
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: val_auc did not improve from 0.95470
# Epoch 27 | loss=0.4112 | val_loss=0.1757 | auc=0.9721 | val_auc=0.9539
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9048 - auc: 0.9719 - loss: 0.4149 - precision: 0.2599 - recall: 0.9135 - val_accuracy: 0.9283 - val_auc: 0.9539 - val_loss: 0.1757 - val_precision: 0.3059 - val_recall: 0.8272 - learning_rate: 0.0010
# Epoch 28/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9058 - auc: 0.9734 - loss: 0.4035 - precision: 0.2626 - recall: 0.9161
# Epoch 28: val_auc improved from 0.95470 to 0.95496, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_1.keras
# Epoch 28 | loss=0.3899 | val_loss=0.1516 | auc=0.9748 | val_auc=0.9550
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9058 - auc: 0.9734 - loss: 0.4034 - precision: 0.2626 - recall: 0.9161 - val_accuracy: 0.9373 - val_auc: 0.9550 - val_loss: 0.1516 - val_precision: 0.3369 - val_recall: 0.8190 - learning_rate: 5.0000e-04
# Epoch 29/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9081 - auc: 0.9750 - loss: 0.3910 - precision: 0.2681 - recall: 0.9204
# Epoch 29: val_auc did not improve from 0.95496
# Epoch 29 | loss=0.3786 | val_loss=0.1517 | auc=0.9762 | val_auc=0.9548
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9081 - auc: 0.9750 - loss: 0.3909 - precision: 0.2682 - recall: 0.9205 - val_accuracy: 0.9386 - val_auc: 0.9548 - val_loss: 0.1517 - val_precision: 0.3424 - val_recall: 0.8190 - learning_rate: 5.0000e-04
# Epoch 30/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9096 - auc: 0.9767 - loss: 0.3774 - precision: 0.2718 - recall: 0.9243
# Epoch 30: val_auc did not improve from 0.95496
# Epoch 30 | loss=0.3697 | val_loss=0.1363 | auc=0.9773 | val_auc=0.9541
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9096 - auc: 0.9767 - loss: 0.3773 - precision: 0.2719 - recall: 0.9244 - val_accuracy: 0.9470 - val_auc: 0.9541 - val_loss: 0.1363 - val_precision: 0.3786 - val_recall: 0.8011 - learning_rate: 5.0000e-04
# Epoch 31/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9118 - auc: 0.9764 - loss: 0.3804 - precision: 0.2768 - recall: 0.9231
# Epoch 31: val_auc did not improve from 0.95496
# Epoch 31 | loss=0.3686 | val_loss=0.1361 | auc=0.9775 | val_auc=0.9535
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9118 - auc: 0.9764 - loss: 0.3802 - precision: 0.2768 - recall: 0.9231 - val_accuracy: 0.9436 - val_auc: 0.9535 - val_loss: 0.1361 - val_precision: 0.3627 - val_recall: 0.8105 - learning_rate: 5.0000e-04
# Epoch 32/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9113 - auc: 0.9779 - loss: 0.3657 - precision: 0.2762 - recall: 0.9280
# Epoch 32: val_auc did not improve from 0.95496
# Epoch 32 | loss=0.3588 | val_loss=0.1397 | auc=0.9785 | val_auc=0.9535
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9113 - auc: 0.9779 - loss: 0.3656 - precision: 0.2763 - recall: 0.9280 - val_accuracy: 0.9439 - val_auc: 0.9535 - val_loss: 0.1397 - val_precision: 0.3639 - val_recall: 0.8054 - learning_rate: 5.0000e-04
# Epoch 33/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9135 - auc: 0.9779 - loss: 0.3657 - precision: 0.2814 - recall: 0.9278
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 33: val_auc did not improve from 0.95496
# Epoch 33 | loss=0.3583 | val_loss=0.1341 | auc=0.9786 | val_auc=0.9529
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9135 - auc: 0.9779 - loss: 0.3656 - precision: 0.2814 - recall: 0.9278 - val_accuracy: 0.9473 - val_auc: 0.9529 - val_loss: 0.1341 - val_precision: 0.3797 - val_recall: 0.8008 - learning_rate: 5.0000e-04
# Epoch 34/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9152 - auc: 0.9795 - loss: 0.3517 - precision: 0.2863 - recall: 0.9322
# Epoch 34: val_auc did not improve from 0.95496
# Epoch 34 | loss=0.3412 | val_loss=0.1292 | auc=0.9804 | val_auc=0.9533
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9152 - auc: 0.9795 - loss: 0.3516 - precision: 0.2863 - recall: 0.9322 - val_accuracy: 0.9471 - val_auc: 0.9533 - val_loss: 0.1292 - val_precision: 0.3791 - val_recall: 0.8037 - learning_rate: 2.5000e-04
# Epoch 35/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9173 - auc: 0.9792 - loss: 0.3556 - precision: 0.2912 - recall: 0.9306
# Epoch 35: val_auc did not improve from 0.95496
# Epoch 35 | loss=0.3441 | val_loss=0.1326 | auc=0.9802 | val_auc=0.9536
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9173 - auc: 0.9792 - loss: 0.3555 - precision: 0.2912 - recall: 0.9306 - val_accuracy: 0.9469 - val_auc: 0.9536 - val_loss: 0.1326 - val_precision: 0.3784 - val_recall: 0.8076 - learning_rate: 2.5000e-04
# Epoch 36/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9186 - auc: 0.9806 - loss: 0.3428 - precision: 0.2951 - recall: 0.9342
# Epoch 36: val_auc did not improve from 0.95496
# Epoch 36 | loss=0.3367 | val_loss=0.1288 | auc=0.9810 | val_auc=0.9535
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9186 - auc: 0.9806 - loss: 0.3427 - precision: 0.2951 - recall: 0.9342 - val_accuracy: 0.9477 - val_auc: 0.9535 - val_loss: 0.1288 - val_precision: 0.3824 - val_recall: 0.8032 - learning_rate: 2.5000e-04
# Epoch 37/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9186 - auc: 0.9810 - loss: 0.3381 - precision: 0.2955 - recall: 0.9363
# Epoch 37: val_auc did not improve from 0.95496
# Epoch 37 | loss=0.3324 | val_loss=0.1264 | auc=0.9814 | val_auc=0.9534
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9186 - auc: 0.9810 - loss: 0.3380 - precision: 0.2955 - recall: 0.9363 - val_accuracy: 0.9491 - val_auc: 0.9534 - val_loss: 0.1264 - val_precision: 0.3896 - val_recall: 0.8006 - learning_rate: 2.5000e-04
# Epoch 38/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9189 - auc: 0.9806 - loss: 0.3420 - precision: 0.2959 - recall: 0.9340
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 38: val_auc did not improve from 0.95496
# Epoch 38 | loss=0.3340 | val_loss=0.1280 | auc=0.9812 | val_auc=0.9532
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9189 - auc: 0.9806 - loss: 0.3420 - precision: 0.2959 - recall: 0.9340 - val_accuracy: 0.9482 - val_auc: 0.9532 - val_loss: 0.1280 - val_precision: 0.3850 - val_recall: 0.8049 - learning_rate: 2.5000e-04
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
#
#    ✅ Fold 1 Complete!
#    Val AUC: 0.956394
#    Best epoch: 28
#
# ======================================================================
# 📊 FOLD 2/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7565 - auc: 0.8492 - loss: 0.9238 - precision: 0.1130 - recall: 0.7753
# Epoch 1: val_auc improved from -inf to 0.92464, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 01 | loss=0.8200 | val_loss=0.2909 | auc=0.8841 | val_auc=0.9246
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step - accuracy: 0.7566 - auc: 0.8493 - loss: 0.9236 - precision: 0.1131 - recall: 0.7753 - val_accuracy: 0.8993 - val_auc: 0.9246 - val_loss: 0.2909 - val_precision: 0.2257 - val_recall: 0.7732 - learning_rate: 0.0010
# Epoch 2/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8512 - auc: 0.9162 - loss: 0.7055 - precision: 0.1676 - recall: 0.8129
# Epoch 2: val_auc improved from 0.92464 to 0.93266, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 02 | loss=0.6946 | val_loss=0.2950 | auc=0.9185 | val_auc=0.9327
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8512 - auc: 0.9162 - loss: 0.7053 - precision: 0.1677 - recall: 0.8129 - val_accuracy: 0.8870 - val_auc: 0.9327 - val_loss: 0.2950 - val_precision: 0.2108 - val_recall: 0.8124 - learning_rate: 0.0010
# Epoch 3/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8589 - auc: 0.9283 - loss: 0.6556 - precision: 0.1782 - recall: 0.8318
# Epoch 3: val_auc improved from 0.93266 to 0.93542, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 03 | loss=0.6536 | val_loss=0.2980 | auc=0.9282 | val_auc=0.9354
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8589 - auc: 0.9283 - loss: 0.6555 - precision: 0.1782 - recall: 0.8318 - val_accuracy: 0.8742 - val_auc: 0.9354 - val_loss: 0.2980 - val_precision: 0.1960 - val_recall: 0.8374 - learning_rate: 0.0010
# Epoch 4/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8634 - auc: 0.9349 - loss: 0.6261 - precision: 0.1849 - recall: 0.8432
# Epoch 4: val_auc improved from 0.93542 to 0.94083, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 04 | loss=0.6257 | val_loss=0.2874 | auc=0.9347 | val_auc=0.9408
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8635 - auc: 0.9349 - loss: 0.6261 - precision: 0.1849 - recall: 0.8432 - val_accuracy: 0.8726 - val_auc: 0.9408 - val_loss: 0.2874 - val_precision: 0.1956 - val_recall: 0.8490 - learning_rate: 0.0010
# Epoch 5/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8677 - auc: 0.9400 - loss: 0.6013 - precision: 0.1913 - recall: 0.8540
# Epoch 5: val_auc improved from 0.94083 to 0.94342, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 05 | loss=0.6005 | val_loss=0.2849 | auc=0.9398 | val_auc=0.9434
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8677 - auc: 0.9400 - loss: 0.6013 - precision: 0.1913 - recall: 0.8540 - val_accuracy: 0.8747 - val_auc: 0.9434 - val_loss: 0.2849 - val_precision: 0.1989 - val_recall: 0.8531 - learning_rate: 0.0010
# Epoch 6/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8703 - auc: 0.9448 - loss: 0.5785 - precision: 0.1957 - recall: 0.8628
# Epoch 6: val_auc improved from 0.94342 to 0.94384, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 06 | loss=0.5826 | val_loss=0.2623 | auc=0.9435 | val_auc=0.9438
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8703 - auc: 0.9447 - loss: 0.5785 - precision: 0.1958 - recall: 0.8628 - val_accuracy: 0.8860 - val_auc: 0.9438 - val_loss: 0.2623 - val_precision: 0.2136 - val_recall: 0.8429 - learning_rate: 0.0010
# Epoch 7/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8734 - auc: 0.9469 - loss: 0.5669 - precision: 0.1998 - recall: 0.8625
# Epoch 7: val_auc improved from 0.94384 to 0.94564, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 07 | loss=0.5663 | val_loss=0.2538 | auc=0.9466 | val_auc=0.9456
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8734 - auc: 0.9469 - loss: 0.5669 - precision: 0.1998 - recall: 0.8625 - val_accuracy: 0.8855 - val_auc: 0.9456 - val_loss: 0.2538 - val_precision: 0.2143 - val_recall: 0.8521 - learning_rate: 0.0010
# Epoch 8/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8749 - auc: 0.9500 - loss: 0.5504 - precision: 0.2028 - recall: 0.8702
# Epoch 8: val_auc improved from 0.94564 to 0.94703, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 08 | loss=0.5526 | val_loss=0.2463 | auc=0.9494 | val_auc=0.9470
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8749 - auc: 0.9500 - loss: 0.5504 - precision: 0.2028 - recall: 0.8702 - val_accuracy: 0.9000 - val_auc: 0.9470 - val_loss: 0.2463 - val_precision: 0.2374 - val_recall: 0.8403 - learning_rate: 0.0010
# Epoch 9/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8783 - auc: 0.9528 - loss: 0.5358 - precision: 0.2086 - recall: 0.8782
# Epoch 9: val_auc improved from 0.94703 to 0.94892, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 09 | loss=0.5400 | val_loss=0.2365 | auc=0.9517 | val_auc=0.9489
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8784 - auc: 0.9528 - loss: 0.5359 - precision: 0.2086 - recall: 0.8781 - val_accuracy: 0.8971 - val_auc: 0.9489 - val_loss: 0.2365 - val_precision: 0.2330 - val_recall: 0.8470 - learning_rate: 0.0010
# Epoch 10/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8796 - auc: 0.9547 - loss: 0.5255 - precision: 0.2111 - recall: 0.8835
# Epoch 10: val_auc did not improve from 0.94892
# Epoch 10 | loss=0.5260 | val_loss=0.2279 | auc=0.9543 | val_auc=0.9483
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8796 - auc: 0.9547 - loss: 0.5256 - precision: 0.2111 - recall: 0.8834 - val_accuracy: 0.9137 - val_auc: 0.9483 - val_loss: 0.2279 - val_precision: 0.2644 - val_recall: 0.8228 - learning_rate: 0.0010
# Epoch 11/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8865 - auc: 0.9564 - loss: 0.5159 - precision: 0.2205 - recall: 0.8769
# Epoch 11: val_auc improved from 0.94892 to 0.94925, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 11 | loss=0.5215 | val_loss=0.2086 | auc=0.9552 | val_auc=0.9492
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8865 - auc: 0.9564 - loss: 0.5159 - precision: 0.2205 - recall: 0.8769 - val_accuracy: 0.9200 - val_auc: 0.9492 - val_loss: 0.2086 - val_precision: 0.2805 - val_recall: 0.8219 - learning_rate: 0.0010
# Epoch 12/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8857 - auc: 0.9580 - loss: 0.5056 - precision: 0.2198 - recall: 0.8805
# Epoch 12: val_auc improved from 0.94925 to 0.94997, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 12 | loss=0.5050 | val_loss=0.1812 | auc=0.9579 | val_auc=0.9500
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8857 - auc: 0.9580 - loss: 0.5056 - precision: 0.2198 - recall: 0.8805 - val_accuracy: 0.9254 - val_auc: 0.9500 - val_loss: 0.1812 - val_precision: 0.2946 - val_recall: 0.8122 - learning_rate: 0.0010
# Epoch 13/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8881 - auc: 0.9592 - loss: 0.4991 - precision: 0.2240 - recall: 0.8830
# Epoch 13: val_auc improved from 0.94997 to 0.95037, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 13 | loss=0.4993 | val_loss=0.1838 | auc=0.9589 | val_auc=0.9504
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8881 - auc: 0.9592 - loss: 0.4991 - precision: 0.2240 - recall: 0.8830 - val_accuracy: 0.9191 - val_auc: 0.9504 - val_loss: 0.1838 - val_precision: 0.2788 - val_recall: 0.8267 - learning_rate: 0.0010
# Epoch 14/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8883 - auc: 0.9604 - loss: 0.4922 - precision: 0.2254 - recall: 0.8902
# Epoch 14: val_auc improved from 0.95037 to 0.95123, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 14 | loss=0.4909 | val_loss=0.1913 | auc=0.9604 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8883 - auc: 0.9604 - loss: 0.4922 - precision: 0.2254 - recall: 0.8902 - val_accuracy: 0.9223 - val_auc: 0.9512 - val_loss: 0.1913 - val_precision: 0.2876 - val_recall: 0.8260 - learning_rate: 0.0010
# Epoch 15/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8924 - auc: 0.9634 - loss: 0.4731 - precision: 0.2327 - recall: 0.8949
# Epoch 15: val_auc did not improve from 0.95123
# Epoch 15 | loss=0.4766 | val_loss=0.1811 | auc=0.9626 | val_auc=0.9498
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8924 - auc: 0.9634 - loss: 0.4732 - precision: 0.2327 - recall: 0.8949 - val_accuracy: 0.9234 - val_auc: 0.9498 - val_loss: 0.1811 - val_precision: 0.2900 - val_recall: 0.8219 - learning_rate: 0.0010
# Epoch 16/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8927 - auc: 0.9633 - loss: 0.4734 - precision: 0.2332 - recall: 0.8947
# Epoch 16: val_auc did not improve from 0.95123
# Epoch 16 | loss=0.4707 | val_loss=0.1770 | auc=0.9635 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8927 - auc: 0.9633 - loss: 0.4734 - precision: 0.2332 - recall: 0.8947 - val_accuracy: 0.9227 - val_auc: 0.9508 - val_loss: 0.1770 - val_precision: 0.2876 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 17/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8909 - auc: 0.9638 - loss: 0.4710 - precision: 0.2307 - recall: 0.8980
# Epoch 17: val_auc improved from 0.95123 to 0.95139, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 17 | loss=0.4661 | val_loss=0.1637 | auc=0.9642 | val_auc=0.9514
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8909 - auc: 0.9638 - loss: 0.4710 - precision: 0.2308 - recall: 0.8980 - val_accuracy: 0.9296 - val_auc: 0.9514 - val_loss: 0.1637 - val_precision: 0.3089 - val_recall: 0.8175 - learning_rate: 0.0010
# Epoch 18/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8919 - auc: 0.9657 - loss: 0.4574 - precision: 0.2330 - recall: 0.9029
# Epoch 18: val_auc improved from 0.95139 to 0.95148, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 18 | loss=0.4590 | val_loss=0.1605 | auc=0.9653 | val_auc=0.9515
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8919 - auc: 0.9657 - loss: 0.4574 - precision: 0.2330 - recall: 0.9029 - val_accuracy: 0.9316 - val_auc: 0.9515 - val_loss: 0.1605 - val_precision: 0.3153 - val_recall: 0.8161 - learning_rate: 0.0010
# Epoch 19/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8923 - auc: 0.9670 - loss: 0.4488 - precision: 0.2339 - recall: 0.9050
# Epoch 19: val_auc improved from 0.95148 to 0.95191, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 19 | loss=0.4509 | val_loss=0.1729 | auc=0.9665 | val_auc=0.9519
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8923 - auc: 0.9670 - loss: 0.4488 - precision: 0.2339 - recall: 0.9050 - val_accuracy: 0.9242 - val_auc: 0.9519 - val_loss: 0.1729 - val_precision: 0.2932 - val_recall: 0.8258 - learning_rate: 0.0010
# Epoch 20/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8910 - auc: 0.9673 - loss: 0.4465 - precision: 0.2322 - recall: 0.9069
# Epoch 20: val_auc improved from 0.95191 to 0.95202, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 20 | loss=0.4456 | val_loss=0.1441 | auc=0.9672 | val_auc=0.9520
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8911 - auc: 0.9673 - loss: 0.4465 - precision: 0.2322 - recall: 0.9069 - val_accuracy: 0.9419 - val_auc: 0.9520 - val_loss: 0.1441 - val_precision: 0.3543 - val_recall: 0.8030 - learning_rate: 0.0010
# Epoch 21/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8975 - auc: 0.9697 - loss: 0.4288 - precision: 0.2437 - recall: 0.9074
# Epoch 21: val_auc did not improve from 0.95202
# Epoch 21 | loss=0.4341 | val_loss=0.1391 | auc=0.9688 | val_auc=0.9509
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8975 - auc: 0.9697 - loss: 0.4289 - precision: 0.2436 - recall: 0.9074 - val_accuracy: 0.9428 - val_auc: 0.9509 - val_loss: 0.1391 - val_precision: 0.3568 - val_recall: 0.7914 - learning_rate: 0.0010
# Epoch 22/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8964 - auc: 0.9695 - loss: 0.4309 - precision: 0.2417 - recall: 0.9080
# Epoch 22: val_auc did not improve from 0.95202
# Epoch 22 | loss=0.4344 | val_loss=0.1546 | auc=0.9689 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8964 - auc: 0.9695 - loss: 0.4310 - precision: 0.2417 - recall: 0.9080 - val_accuracy: 0.9351 - val_auc: 0.9512 - val_loss: 0.1546 - val_precision: 0.3268 - val_recall: 0.8069 - learning_rate: 0.0010
# Epoch 23/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8966 - auc: 0.9699 - loss: 0.4280 - precision: 0.2428 - recall: 0.9134
# Epoch 23: val_auc did not improve from 0.95202
# Epoch 23 | loss=0.4263 | val_loss=0.1356 | auc=0.9700 | val_auc=0.9507
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8966 - auc: 0.9699 - loss: 0.4280 - precision: 0.2428 - recall: 0.9134 - val_accuracy: 0.9451 - val_auc: 0.9507 - val_loss: 0.1356 - val_precision: 0.3680 - val_recall: 0.7931 - learning_rate: 0.0010
# Epoch 24/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8992 - auc: 0.9713 - loss: 0.4178 - precision: 0.2476 - recall: 0.9142
# Epoch 24: val_auc did not improve from 0.95202
# Epoch 24 | loss=0.4189 | val_loss=0.1449 | auc=0.9710 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8991 - auc: 0.9713 - loss: 0.4178 - precision: 0.2476 - recall: 0.9142 - val_accuracy: 0.9405 - val_auc: 0.9508 - val_loss: 0.1449 - val_precision: 0.3477 - val_recall: 0.7999 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8985 - auc: 0.9717 - loss: 0.4144 - precision: 0.2466 - recall: 0.9153
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: val_auc did not improve from 0.95202
# Epoch 25 | loss=0.4152 | val_loss=0.1385 | auc=0.9714 | val_auc=0.9511
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8985 - auc: 0.9717 - loss: 0.4144 - precision: 0.2466 - recall: 0.9153 - val_accuracy: 0.9400 - val_auc: 0.9511 - val_loss: 0.1385 - val_precision: 0.3465 - val_recall: 0.8061 - learning_rate: 0.0010
# Epoch 26/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8995 - auc: 0.9725 - loss: 0.4096 - precision: 0.2493 - recall: 0.9199
# Epoch 26: val_auc improved from 0.95202 to 0.95211, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_2.keras
# Epoch 26 | loss=0.3993 | val_loss=0.1206 | auc=0.9736 | val_auc=0.9521
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8996 - auc: 0.9725 - loss: 0.4095 - precision: 0.2493 - recall: 0.9199 - val_accuracy: 0.9516 - val_auc: 0.9521 - val_loss: 0.1206 - val_precision: 0.4016 - val_recall: 0.7844 - learning_rate: 5.0000e-04
# Epoch 27/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9049 - auc: 0.9756 - loss: 0.3849 - precision: 0.2602 - recall: 0.9226
# Epoch 27: val_auc did not improve from 0.95211
# Epoch 27 | loss=0.3835 | val_loss=0.1135 | auc=0.9756 | val_auc=0.9512
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9049 - auc: 0.9756 - loss: 0.3849 - precision: 0.2602 - recall: 0.9226 - val_accuracy: 0.9558 - val_auc: 0.9512 - val_loss: 0.1135 - val_precision: 0.4267 - val_recall: 0.7691 - learning_rate: 5.0000e-04
# Epoch 28/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9080 - auc: 0.9758 - loss: 0.3825 - precision: 0.2668 - recall: 0.9219
# Epoch 28: val_auc did not improve from 0.95211
# Epoch 28 | loss=0.3785 | val_loss=0.1089 | auc=0.9761 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9080 - auc: 0.9758 - loss: 0.3824 - precision: 0.2668 - recall: 0.9219 - val_accuracy: 0.9579 - val_auc: 0.9502 - val_loss: 0.1089 - val_precision: 0.4413 - val_recall: 0.7657 - learning_rate: 5.0000e-04
# Epoch 29/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9090 - auc: 0.9769 - loss: 0.3749 - precision: 0.2695 - recall: 0.9259
# Epoch 29: val_auc did not improve from 0.95211
# Epoch 29 | loss=0.3732 | val_loss=0.1071 | auc=0.9769 | val_auc=0.9504
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9090 - auc: 0.9769 - loss: 0.3749 - precision: 0.2695 - recall: 0.9259 - val_accuracy: 0.9583 - val_auc: 0.9504 - val_loss: 0.1071 - val_precision: 0.4444 - val_recall: 0.7633 - learning_rate: 5.0000e-04
# Epoch 30/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9092 - auc: 0.9776 - loss: 0.3676 - precision: 0.2704 - recall: 0.9284
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 30: val_auc did not improve from 0.95211
# Epoch 30 | loss=0.3672 | val_loss=0.1093 | auc=0.9775 | val_auc=0.9496
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9092 - auc: 0.9776 - loss: 0.3676 - precision: 0.2704 - recall: 0.9284 - val_accuracy: 0.9571 - val_auc: 0.9496 - val_loss: 0.1093 - val_precision: 0.4356 - val_recall: 0.7667 - learning_rate: 5.0000e-04
# Epoch 31/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9080 - auc: 0.9789 - loss: 0.3552 - precision: 0.2685 - recall: 0.9349
# Epoch 31: val_auc did not improve from 0.95211
# Epoch 31 | loss=0.3523 | val_loss=0.1030 | auc=0.9792 | val_auc=0.9472
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9080 - auc: 0.9789 - loss: 0.3552 - precision: 0.2686 - recall: 0.9349 - val_accuracy: 0.9589 - val_auc: 0.9472 - val_loss: 0.1030 - val_precision: 0.4484 - val_recall: 0.7582 - learning_rate: 2.5000e-04
# Epoch 32/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9117 - auc: 0.9797 - loss: 0.3487 - precision: 0.2770 - recall: 0.9352
# Epoch 32: val_auc did not improve from 0.95211
# Epoch 32 | loss=0.3479 | val_loss=0.1019 | auc=0.9797 | val_auc=0.9481
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9117 - auc: 0.9797 - loss: 0.3487 - precision: 0.2770 - recall: 0.9352 - val_accuracy: 0.9600 - val_auc: 0.9481 - val_loss: 0.1019 - val_precision: 0.4566 - val_recall: 0.7577 - learning_rate: 2.5000e-04
# Epoch 33/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9122 - auc: 0.9803 - loss: 0.3433 - precision: 0.2784 - recall: 0.9377
# Epoch 33: val_auc did not improve from 0.95211
# Epoch 33 | loss=0.3419 | val_loss=0.1022 | auc=0.9803 | val_auc=0.9467
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9122 - auc: 0.9803 - loss: 0.3433 - precision: 0.2784 - recall: 0.9377 - val_accuracy: 0.9591 - val_auc: 0.9467 - val_loss: 0.1022 - val_precision: 0.4504 - val_recall: 0.7628 - learning_rate: 2.5000e-04
# Epoch 34/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9108 - auc: 0.9799 - loss: 0.3456 - precision: 0.2751 - recall: 0.9377
# Epoch 34: val_auc did not improve from 0.95211
# Epoch 34 | loss=0.3414 | val_loss=0.1004 | auc=0.9803 | val_auc=0.9460
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9108 - auc: 0.9799 - loss: 0.3455 - precision: 0.2752 - recall: 0.9377 - val_accuracy: 0.9605 - val_auc: 0.9460 - val_loss: 0.1004 - val_precision: 0.4607 - val_recall: 0.7594 - learning_rate: 2.5000e-04
# Epoch 35/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9135 - auc: 0.9808 - loss: 0.3381 - precision: 0.2816 - recall: 0.9390
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 35: val_auc did not improve from 0.95211
# Epoch 35 | loss=0.3359 | val_loss=0.1013 | auc=0.9809 | val_auc=0.9448
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9135 - auc: 0.9808 - loss: 0.3381 - precision: 0.2816 - recall: 0.9390 - val_accuracy: 0.9595 - val_auc: 0.9448 - val_loss: 0.1013 - val_precision: 0.4528 - val_recall: 0.7585 - learning_rate: 2.5000e-04
# Epoch 36/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9133 - auc: 0.9808 - loss: 0.3383 - precision: 0.2817 - recall: 0.9419
# Epoch 36: val_auc did not improve from 0.95211
# Epoch 36 | loss=0.3320 | val_loss=0.0965 | auc=0.9813 | val_auc=0.9457
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9134 - auc: 0.9808 - loss: 0.3383 - precision: 0.2817 - recall: 0.9419 - val_accuracy: 0.9632 - val_auc: 0.9457 - val_loss: 0.0965 - val_precision: 0.4832 - val_recall: 0.7498 - learning_rate: 1.2500e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
#
#    ✅ Fold 2 Complete!
#    Val AUC: 0.954323
#    Best epoch: 26
#
# ======================================================================
# 📊 FOLD 3/5
# ======================================================================
#    Train: 472,432 samples (3.50% fraud)
#    Val:   118,108 samples (3.50% fraud)
#
#    🚀 Training...
# Epoch 1/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8102 - auc: 0.8392 - loss: 0.9412 - precision: 0.1215 - recall: 0.7088
# Epoch 1: val_auc improved from -inf to 0.92086, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 01 | loss=0.8269 | val_loss=0.3016 | auc=0.8832 | val_auc=0.9209
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 26s 29ms/step - accuracy: 0.8103 - auc: 0.8393 - loss: 0.9410 - precision: 0.1216 - recall: 0.7089 - val_accuracy: 0.8934 - val_auc: 0.9209 - val_loss: 0.3016 - val_precision: 0.2152 - val_recall: 0.7730 - learning_rate: 0.0010
# Epoch 2/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8432 - auc: 0.9138 - loss: 0.7127 - precision: 0.1597 - recall: 0.8220
# Epoch 2: val_auc improved from 0.92086 to 0.93006, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 02 | loss=0.6961 | val_loss=0.3050 | auc=0.9184 | val_auc=0.9301
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8433 - auc: 0.9139 - loss: 0.7125 - precision: 0.1598 - recall: 0.8220 - val_accuracy: 0.8696 - val_auc: 0.9301 - val_loss: 0.3050 - val_precision: 0.1887 - val_recall: 0.8270 - learning_rate: 0.0010
# Epoch 3/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8563 - auc: 0.9258 - loss: 0.6637 - precision: 0.1739 - recall: 0.8338
# Epoch 3: val_auc improved from 0.93006 to 0.93529, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 03 | loss=0.6549 | val_loss=0.2922 | auc=0.9284 | val_auc=0.9353
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8564 - auc: 0.9259 - loss: 0.6635 - precision: 0.1739 - recall: 0.8339 - val_accuracy: 0.8778 - val_auc: 0.9353 - val_loss: 0.2922 - val_precision: 0.1999 - val_recall: 0.8297 - learning_rate: 0.0010
# Epoch 4/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8662 - auc: 0.9317 - loss: 0.6357 - precision: 0.1849 - recall: 0.8345
# Epoch 4: val_auc improved from 0.93529 to 0.93961, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 04 | loss=0.6245 | val_loss=0.2735 | auc=0.9347 | val_auc=0.9396
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8662 - auc: 0.9317 - loss: 0.6357 - precision: 0.1849 - recall: 0.8345 - val_accuracy: 0.8948 - val_auc: 0.9396 - val_loss: 0.2735 - val_precision: 0.2253 - val_recall: 0.8224 - learning_rate: 0.0010
# Epoch 5/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8700 - auc: 0.9380 - loss: 0.6080 - precision: 0.1912 - recall: 0.8472
# Epoch 5: val_auc improved from 0.93961 to 0.94302, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 05 | loss=0.5997 | val_loss=0.2647 | auc=0.9400 | val_auc=0.9430
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8700 - auc: 0.9380 - loss: 0.6080 - precision: 0.1912 - recall: 0.8472 - val_accuracy: 0.8984 - val_auc: 0.9430 - val_loss: 0.2647 - val_precision: 0.2324 - val_recall: 0.8260 - learning_rate: 0.0010
# Epoch 6/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8748 - auc: 0.9419 - loss: 0.5902 - precision: 0.1985 - recall: 0.8552
# Epoch 6: val_auc improved from 0.94302 to 0.94386, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 06 | loss=0.5830 | val_loss=0.2498 | auc=0.9436 | val_auc=0.9439
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8748 - auc: 0.9419 - loss: 0.5901 - precision: 0.1985 - recall: 0.8552 - val_accuracy: 0.8981 - val_auc: 0.9439 - val_loss: 0.2498 - val_precision: 0.2332 - val_recall: 0.8355 - learning_rate: 0.0010
# Epoch 7/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8787 - auc: 0.9449 - loss: 0.5752 - precision: 0.2046 - recall: 0.8608
# Epoch 7: val_auc improved from 0.94386 to 0.94566, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_3.keras
# Epoch 07 | loss=0.5663 | val_loss=0.2378 | auc=0.9468 | val_auc=0.9457
# ...
# Epoch 19/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8996 - auc: 0.9652 - loss: 0.4593 - precision: 0.2431 - recall: 0.8922
# Epoch 19: val_auc improved from 0.95059 to 0.95087, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 19 | loss=0.4566 | val_loss=0.1908 | auc=0.9658 | val_auc=0.9509
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8996 - auc: 0.9652 - loss: 0.4592 - precision: 0.2431 - recall: 0.8922 - val_accuracy: 0.9264 - val_auc: 0.9509 - val_loss: 0.1908 - val_precision: 0.2988 - val_recall: 0.8193 - learning_rate: 0.0010
# Epoch 20/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8980 - auc: 0.9660 - loss: 0.4537 - precision: 0.2409 - recall: 0.8973
# Epoch 20: val_auc did not improve from 0.95087
# Epoch 20 | loss=0.4491 | val_loss=0.1933 | auc=0.9669 | val_auc=0.9502
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8980 - auc: 0.9660 - loss: 0.4536 - precision: 0.2409 - recall: 0.8974 - val_accuracy: 0.9236 - val_auc: 0.9502 - val_loss: 0.1933 - val_precision: 0.2909 - val_recall: 0.8241 - learning_rate: 0.0010
# Epoch 21/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8955 - auc: 0.9660 - loss: 0.4538 - precision: 0.2368 - recall: 0.9003
# Epoch 21: val_auc did not improve from 0.95087
# Epoch 21 | loss=0.4474 | val_loss=0.1818 | auc=0.9671 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8955 - auc: 0.9660 - loss: 0.4537 - precision: 0.2368 - recall: 0.9004 - val_accuracy: 0.9242 - val_auc: 0.9508 - val_loss: 0.1818 - val_precision: 0.2923 - val_recall: 0.8212 - learning_rate: 0.0010
# Epoch 22/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8955 - auc: 0.9664 - loss: 0.4515 - precision: 0.2370 - recall: 0.9018
# Epoch 22: val_auc improved from 0.95087 to 0.95097, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 22 | loss=0.4420 | val_loss=0.1695 | auc=0.9679 | val_auc=0.9510
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8955 - auc: 0.9664 - loss: 0.4514 - precision: 0.2370 - recall: 0.9018 - val_accuracy: 0.9362 - val_auc: 0.9510 - val_loss: 0.1695 - val_precision: 0.3302 - val_recall: 0.8016 - learning_rate: 0.0010
# Epoch 23/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8999 - auc: 0.9684 - loss: 0.4375 - precision: 0.2456 - recall: 0.9049
# Epoch 23: val_auc improved from 0.95097 to 0.95202, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 23 | loss=0.4340 | val_loss=0.1702 | auc=0.9691 | val_auc=0.9520
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8999 - auc: 0.9684 - loss: 0.4375 - precision: 0.2456 - recall: 0.9049 - val_accuracy: 0.9322 - val_auc: 0.9520 - val_loss: 0.1702 - val_precision: 0.3167 - val_recall: 0.8089 - learning_rate: 0.0010
# Epoch 24/50
# 454/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8994 - auc: 0.9698 - loss: 0.4273 - precision: 0.2452 - recall: 0.9101
# Epoch 24: val_auc did not improve from 0.95202
# Epoch 24 | loss=0.4267 | val_loss=0.1780 | auc=0.9700 | val_auc=0.9509
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8994 - auc: 0.9698 - loss: 0.4273 - precision: 0.2453 - recall: 0.9101 - val_accuracy: 0.9315 - val_auc: 0.9509 - val_loss: 0.1780 - val_precision: 0.3148 - val_recall: 0.8144 - learning_rate: 0.0010
# Epoch 25/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9014 - auc: 0.9703 - loss: 0.4236 - precision: 0.2488 - recall: 0.9089
# Epoch 25: val_auc did not improve from 0.95202
# Epoch 25 | loss=0.4217 | val_loss=0.1683 | auc=0.9707 | val_auc=0.9517
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9014 - auc: 0.9703 - loss: 0.4236 - precision: 0.2488 - recall: 0.9089 - val_accuracy: 0.9340 - val_auc: 0.9517 - val_loss: 0.1683 - val_precision: 0.3228 - val_recall: 0.8076 - learning_rate: 0.0010
# Epoch 26/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9044 - auc: 0.9714 - loss: 0.4149 - precision: 0.2551 - recall: 0.9097
# Epoch 26: val_auc did not improve from 0.95202
# Epoch 26 | loss=0.4150 | val_loss=0.1643 | auc=0.9716 | val_auc=0.9501
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9044 - auc: 0.9714 - loss: 0.4149 - precision: 0.2551 - recall: 0.9097 - val_accuracy: 0.9353 - val_auc: 0.9501 - val_loss: 0.1643 - val_precision: 0.3281 - val_recall: 0.8103 - learning_rate: 0.0010
# Epoch 27/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9038 - auc: 0.9719 - loss: 0.4119 - precision: 0.2546 - recall: 0.9143
# Epoch 27: val_auc improved from 0.95202 to 0.95370, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 27 | loss=0.4129 | val_loss=0.1822 | auc=0.9719 | val_auc=0.9537
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9038 - auc: 0.9719 - loss: 0.4119 - precision: 0.2546 - recall: 0.9143 - val_accuracy: 0.9241 - val_auc: 0.9537 - val_loss: 0.1822 - val_precision: 0.2941 - val_recall: 0.8352 - learning_rate: 0.0010
# Epoch 28/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9003 - auc: 0.9707 - loss: 0.4210 - precision: 0.2472 - recall: 0.9119
# Epoch 28: val_auc did not improve from 0.95370
# Epoch 28 | loss=0.4166 | val_loss=0.1675 | auc=0.9715 | val_auc=0.9525
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9003 - auc: 0.9708 - loss: 0.4210 - precision: 0.2473 - recall: 0.9119 - val_accuracy: 0.9387 - val_auc: 0.9525 - val_loss: 0.1675 - val_precision: 0.3407 - val_recall: 0.8050 - learning_rate: 0.0010
# Epoch 29/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9033 - auc: 0.9728 - loss: 0.4044 - precision: 0.2534 - recall: 0.9136
# Epoch 29: val_auc did not improve from 0.95370
# Epoch 29 | loss=0.3992 | val_loss=0.1479 | auc=0.9736 | val_auc=0.9524
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9033 - auc: 0.9728 - loss: 0.4043 - precision: 0.2535 - recall: 0.9137 - val_accuracy: 0.9392 - val_auc: 0.9524 - val_loss: 0.1479 - val_precision: 0.3434 - val_recall: 0.8091 - learning_rate: 0.0010
# Epoch 30/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9054 - auc: 0.9727 - loss: 0.4062 - precision: 0.2577 - recall: 0.9138
# Epoch 30: val_auc did not improve from 0.95370
# Epoch 30 | loss=0.4013 | val_loss=0.1558 | auc=0.9734 | val_auc=0.9517
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9054 - auc: 0.9727 - loss: 0.4062 - precision: 0.2577 - recall: 0.9138 - val_accuracy: 0.9390 - val_auc: 0.9517 - val_loss: 0.1558 - val_precision: 0.3422 - val_recall: 0.8067 - learning_rate: 0.0010
# Epoch 31/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9065 - auc: 0.9742 - loss: 0.3940 - precision: 0.2609 - recall: 0.9206
# Epoch 31: val_auc did not improve from 0.95370
# Epoch 31 | loss=0.3914 | val_loss=0.1427 | auc=0.9746 | val_auc=0.9507
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9065 - auc: 0.9742 - loss: 0.3940 - precision: 0.2609 - recall: 0.9206 - val_accuracy: 0.9421 - val_auc: 0.9507 - val_loss: 0.1427 - val_precision: 0.3544 - val_recall: 0.7982 - learning_rate: 0.0010
# Epoch 32/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9081 - auc: 0.9738 - loss: 0.3981 - precision: 0.2639 - recall: 0.9171
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_auc did not improve from 0.95370
# Epoch 32 | loss=0.3974 | val_loss=0.1556 | auc=0.9740 | val_auc=0.9533
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9081 - auc: 0.9738 - loss: 0.3981 - precision: 0.2639 - recall: 0.9171 - val_accuracy: 0.9394 - val_auc: 0.9533 - val_loss: 0.1556 - val_precision: 0.3443 - val_recall: 0.8101 - learning_rate: 0.0010
# Epoch 33/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9098 - auc: 0.9759 - loss: 0.3810 - precision: 0.2686 - recall: 0.9235
# Epoch 33: val_auc did not improve from 0.95370
# Epoch 33 | loss=0.3718 | val_loss=0.1352 | auc=0.9771 | val_auc=0.9526
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9098 - auc: 0.9759 - loss: 0.3810 - precision: 0.2686 - recall: 0.9235 - val_accuracy: 0.9431 - val_auc: 0.9526 - val_loss: 0.1352 - val_precision: 0.3598 - val_recall: 0.8028 - learning_rate: 5.0000e-04
# Epoch 34/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9107 - auc: 0.9775 - loss: 0.3667 - precision: 0.2710 - recall: 0.9260
# Epoch 34: val_auc did not improve from 0.95370
# Epoch 34 | loss=0.3588 | val_loss=0.1339 | auc=0.9785 | val_auc=0.9520
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9107 - auc: 0.9775 - loss: 0.3666 - precision: 0.2710 - recall: 0.9260 - val_accuracy: 0.9444 - val_auc: 0.9520 - val_loss: 0.1339 - val_precision: 0.3660 - val_recall: 0.8026 - learning_rate: 5.0000e-04
# Epoch 35/50
# 458/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9147 - auc: 0.9791 - loss: 0.3528 - precision: 0.2815 - recall: 0.9331
# Epoch 35: val_auc did not improve from 0.95370
# Epoch 35 | loss=0.3499 | val_loss=0.1367 | auc=0.9795 | val_auc=0.9529
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9147 - auc: 0.9791 - loss: 0.3528 - precision: 0.2814 - recall: 0.9332 - val_accuracy: 0.9409 - val_auc: 0.9529 - val_loss: 0.1367 - val_precision: 0.3509 - val_recall: 0.8101 - learning_rate: 5.0000e-04
# Epoch 36/50
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9148 - auc: 0.9796 - loss: 0.3500 - precision: 0.2816 - recall: 0.9336
# Epoch 36: val_auc improved from 0.95370 to 0.95374, saving model to /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/models/best_model_fold_5.keras
# Epoch 36 | loss=0.3542 | val_loss=0.1413 | auc=0.9792 | val_auc=0.9537
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9148 - auc: 0.9796 - loss: 0.3500 - precision: 0.2816 - recall: 0.9336 - val_accuracy: 0.9417 - val_auc: 0.9537 - val_loss: 0.1413 - val_precision: 0.3543 - val_recall: 0.8098 - learning_rate: 5.0000e-04
# Epoch 37/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9159 - auc: 0.9794 - loss: 0.3515 - precision: 0.2836 - recall: 0.9285
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_auc did not improve from 0.95374
# Epoch 37 | loss=0.3462 | val_loss=0.1382 | auc=0.9800 | val_auc=0.9523
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9159 - auc: 0.9794 - loss: 0.3514 - precision: 0.2836 - recall: 0.9285 - val_accuracy: 0.9422 - val_auc: 0.9523 - val_loss: 0.1382 - val_precision: 0.3560 - val_recall: 0.8055 - learning_rate: 5.0000e-04
# Epoch 38/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9165 - auc: 0.9804 - loss: 0.3409 - precision: 0.2865 - recall: 0.9373
# Epoch 38: val_auc did not improve from 0.95374
# Epoch 38 | loss=0.3331 | val_loss=0.1302 | auc=0.9813 | val_auc=0.9510
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9166 - auc: 0.9805 - loss: 0.3408 - precision: 0.2865 - recall: 0.9373 - val_accuracy: 0.9434 - val_auc: 0.9510 - val_loss: 0.1302 - val_precision: 0.3610 - val_recall: 0.8038 - learning_rate: 2.5000e-04
# Epoch 39/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9166 - auc: 0.9809 - loss: 0.3358 - precision: 0.2868 - recall: 0.9384
# Epoch 39: val_auc did not improve from 0.95374
# Epoch 39 | loss=0.3250 | val_loss=0.1253 | auc=0.9822 | val_auc=0.9496
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9166 - auc: 0.9809 - loss: 0.3357 - precision: 0.2869 - recall: 0.9384 - val_accuracy: 0.9472 - val_auc: 0.9496 - val_loss: 0.1253 - val_precision: 0.3791 - val_recall: 0.7972 - learning_rate: 2.5000e-04
# Epoch 40/50
# 455/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9207 - auc: 0.9823 - loss: 0.3232 - precision: 0.2977 - recall: 0.9411
# Epoch 40: val_auc did not improve from 0.95374
# Epoch 40 | loss=0.3213 | val_loss=0.1275 | auc=0.9826 | val_auc=0.9503
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9207 - auc: 0.9823 - loss: 0.3232 - precision: 0.2978 - recall: 0.9411 - val_accuracy: 0.9464 - val_auc: 0.9503 - val_loss: 0.1275 - val_precision: 0.3752 - val_recall: 0.7977 - learning_rate: 2.5000e-04
# Epoch 41/50
# 461/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9176 - auc: 0.9818 - loss: 0.3272 - precision: 0.2891 - recall: 0.9361
# Epoch 41: val_auc did not improve from 0.95374
# Epoch 41 | loss=0.3212 | val_loss=0.1259 | auc=0.9826 | val_auc=0.9499
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9176 - auc: 0.9818 - loss: 0.3272 - precision: 0.2891 - recall: 0.9362 - val_accuracy: 0.9471 - val_auc: 0.9499 - val_loss: 0.1259 - val_precision: 0.3788 - val_recall: 0.7989 - learning_rate: 2.5000e-04
# Epoch 42/50
# 456/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9191 - auc: 0.9825 - loss: 0.3223 - precision: 0.2938 - recall: 0.9424
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 42: val_auc did not improve from 0.95374
# Epoch 42 | loss=0.3186 | val_loss=0.1226 | auc=0.9828 | val_auc=0.9482
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9192 - auc: 0.9825 - loss: 0.3222 - precision: 0.2938 - recall: 0.9424 - val_accuracy: 0.9475 - val_auc: 0.9482 - val_loss: 0.1226 - val_precision: 0.3808 - val_recall: 0.7968 - learning_rate: 2.5000e-04
# Epoch 43/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9216 - auc: 0.9827 - loss: 0.3177 - precision: 0.3006 - recall: 0.9447
# Epoch 43: val_auc did not improve from 0.95374
# Epoch 43 | loss=0.3111 | val_loss=0.1226 | auc=0.9835 | val_auc=0.9500
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9216 - auc: 0.9827 - loss: 0.3177 - precision: 0.3006 - recall: 0.9447 - val_accuracy: 0.9482 - val_auc: 0.9500 - val_loss: 0.1226 - val_precision: 0.3841 - val_recall: 0.7972 - learning_rate: 1.2500e-04
# Epoch 44/50
# 459/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9227 - auc: 0.9835 - loss: 0.3105 - precision: 0.3036 - recall: 0.9446
# Epoch 44: val_auc did not improve from 0.95374
# Epoch 44 | loss=0.3079 | val_loss=0.1204 | auc=0.9839 | val_auc=0.9497
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9227 - auc: 0.9835 - loss: 0.3104 - precision: 0.3036 - recall: 0.9446 - val_accuracy: 0.9493 - val_auc: 0.9497 - val_loss: 0.1204 - val_precision: 0.3898 - val_recall: 0.7955 - learning_rate: 1.2500e-04
# Epoch 45/50
# 460/462 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9231 - auc: 0.9838 - loss: 0.3081 - precision: 0.3053 - recall: 0.9476
# Epoch 45: val_auc did not improve from 0.95374
# Epoch 45 | loss=0.3073 | val_loss=0.1192 | auc=0.9839 | val_auc=0.9507
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9231 - auc: 0.9838 - loss: 0.3081 - precision: 0.3054 - recall: 0.9476 - val_accuracy: 0.9506 - val_auc: 0.9507 - val_loss: 0.1192 - val_precision: 0.3971 - val_recall: 0.7951 - learning_rate: 1.2500e-04
# Epoch 46/50
# 457/462 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9238 - auc: 0.9836 - loss: 0.3103 - precision: 0.3065 - recall: 0.9429
# Epoch 46: val_auc did not improve from 0.95374
# Epoch 46 | loss=0.3062 | val_loss=0.1211 | auc=0.9840 | val_auc=0.9508
# 462/462 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9238 - auc: 0.9836 - loss: 0.3103 - precision: 0.3065 - recall: 0.9430 - val_accuracy: 0.9496 - val_auc: 0.9508 - val_loss: 0.1211 - val_precision: 0.3919 - val_recall: 0.7987 - learning_rate: 1.2500e-04
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 36.
#
#    ✅ Fold 5 Complete!
#    Val AUC: 0.955282
#    Best epoch: 36
#
# ======================================================================
# 📊 CROSS-VALIDATION RESULTS
# ======================================================================
#
# Fold AUC Scores:
#    Fold 1: 0.956394
#    Fold 2: 0.954323
#    Fold 3: 0.956342
#    Fold 4: 0.953264
#    Fold 5: 0.955282
#
# 🏆 Summary:
#    Mean AUC: 0.955121
#    Std AUC:  0.001202
#    Min AUC:  0.953264
#    Max AUC:  0.956394
#
# ✅ CV results saved to: /content/drive/MyDrive/ML_Projects/ieee-fraud-detection/results/cv_results.json
